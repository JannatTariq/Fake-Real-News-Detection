# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install contractions
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 2.8 MB/s eta 0:00:00
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 12.3 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24

# %%
import seaborn as sns
import string
import re
import nltk
import spacy
import contractions
import math

from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
import unicodedata
from tqdm import trange
from nltk import tokenize
from nltk.corpus import words, names
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from nltk.probability import FreqDist
from textblob import TextBlob, Word, Blobber
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import warnings
warnings.filterwarnings('ignore')
sns.set_style('dark')
plt.rcParams['figure.figsize'] = (17,10)
plt.rcParams['font.size'] = 20

#nlp = spacy.load('en_core_web_sm')

# %%
df1=pd.read_csv("True.csv")
df2=pd.read_csv("Fake.csv")

# %%
df1.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df1.shape
# Out:
# (21417, 4)

# %%
df1.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB

# %%
df1.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
df1.describe()
# Out:
#                                                     title  \
# count                                               21417
# unique                                              20826
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14
#
#                                                      text       subject  \
# count                                               21417         21417
# unique                                              21192             2
# top     (Reuters) - Highlights for U.S. President Dona...  politicsNews
# freq                                                    8         11272
#
#                       date
# count                21417
# unique                 716
# top     December 20, 2017
# freq                   182

# %%
df1.duplicated().sum()
# Out:
# 206

# %%
df1.drop_duplicates(inplace=True)
df1.duplicated().sum()
# Out:
# 0

# %%
df2.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df2.shape
# Out:
# (23481, 4)

# %%
df2.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %%
df2.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
df2.describe()
# Out:
#                                                     title   text subject  \
# count                                               23481  23481   23481
# unique                                              17903  17455       6
# top     MEDIA IGNORES Time That Bill Clinton FIRED His...           News
# freq                                                    6    626    9050
#
#                 date
# count          23481
# unique          1681
# top     May 10, 2017
# freq              46

# %%
df2.duplicated().sum()
# Out:
# 3

# %%
df2.drop_duplicates(inplace=True)
df2.duplicated().sum()
# Out:
# 0

# %%
df1.shape
# Out:
# (21211, 4)

# %%
df2.shape
# Out:
# (23478, 4)

# %%
# Calculate lengths of articles
len_df1 = df1['text'].apply(len)
len_df2 = df2['text'].apply(len)

# Plot histograms with improved visual clarity
plt.hist(len_df1, bins=50, color='green', label='Real News')
plt.title('Distribution of Article Lengths by Type')
plt.xlabel('Length of Articles (Characters)')
plt.ylabel('Number of Articles')
plt.legend()
plt.grid(True)
plt.show()

plt.hist(len_df2, bins=50, color='red', label='Fake News')
plt.title('Distribution of Article Lengths by Type')
plt.xlabel('Length of Articles (Characters)')
plt.ylabel('Number of Articles')
plt.legend()
plt.grid(True)
plt.show()

# %%
def common_occurring_words(texts, num_words=10):
    # Tokenize all texts at once
    all_words = nltk.word_tokenize(" ".join(texts).lower())

    # Use set for faster lookup
    stop_words = set(nltk.corpus.stopwords.words('english'))

    # Filter out non-alpha and stop words in one step
    words = [word for word in all_words if word.isalpha() and word not in stop_words]

    # Count word occurrences
    word_counts = Counter(words)

    return word_counts.most_common(num_words)

words_df1 = common_occurring_words(df1['text'])
words_df2 = common_occurring_words(df2['text'])

print('Real News:', words_df1)
print('Fake News:', words_df2)
# Out:
# Real News: [('said', 97839), ('trump', 53639), ('would', 31168), ('reuters', 28118), ('president', 26107), ('state', 19525), ('government', 18007), ('new', 16625), ('house', 16365), ('states', 16278)]
# Fake News: [('trump', 74241), ('said', 31148), ('people', 26015), ('president', 25771), ('would', 23460), ('one', 22992), ('clinton', 18080), ('obama', 17920), ('like', 17659), ('donald', 17235)]

# %%
df1['label'] = 1
df2['label'] = 0

# %%
df1.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
df2.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
frames=[df1,df2]
df=pd.concat(frames,ignore_index=True)

# %%
df.shape
# Out:
# (44689, 5)

# %%
df.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'label'], dtype='object')

# %%
df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
df.tail()
# Out:
#                                                    title  \
# 44684  McPain: John McCain Furious That Iran Treated ...
# 44685  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 44686  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 44687  How to Blow $700 Million: Al Jazeera America F...
# 44688  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 44684  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 44685  21st Century Wire says It s a familiar theme. ...  Middle-east
# 44686  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 44687  21st Century Wire says Al Jazeera America will...  Middle-east
# 44688  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                    date  label
# 44684  January 16, 2016      0
# 44685  January 16, 2016      0
# 44686  January 15, 2016      0
# 44687  January 14, 2016      0
# 44688  January 12, 2016      0

# %%
labels = {0: 'Fake News', 1: 'Real News'}

# Plot the count of each category with labels
sns.countplot(x='label', data=df)
plt.xlabel('News Type')
plt.ylabel('Count')
plt.title('Distribution of News Types')
plt.xticks(ticks=[0, 1], labels=[labels[0], labels[1]])  # Set custom labels for x-axis ticks
plt.show()

# %%
unique_subjects_real = df1['subject'].unique()
print("subjects in real news dataset",unique_subjects_real)

unique_subjects_fake = df2['subject'].unique()
print("subjects in fake news dataset",unique_subjects_fake)
# Out:
# subjects in real news dataset ['politicsNews' 'worldnews']
# subjects in fake news dataset ['News' 'politics' 'Government News' 'left-news' 'US_News' 'Middle-east']

# %%
sns.barplot(y=df['subject'].value_counts().index,x=df['subject'].value_counts(),
            orient='h')
# Out:
# <Axes: xlabel='count', ylabel='subject'>

# %%
df.drop(columns=["date","subject"],inplace=True)

# %%
df.columns
# Out:
# Index(['title', 'text', 'label'], dtype='object')

# %%
# Download NLTK resources (word corpus)
nltk.download('words')

# Get English word set from NLTK
english_words = set(nltk.corpus.words.words())

# Function to filter out non-English words
def filter_non_english(text):
    return ' '.join(w for w in nltk.wordpunct_tokenize(text) if w.lower() in english_words or not w.isalpha())

# Apply the function to the column
df['text'] = df['text'].apply(filter_non_english)
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
#removing header tags from columns
df['text'] = df['text'].str.replace(r'\b\w+\s+\(Reuters\) -', '', regex=True)
#removing source links from columns
df['text'] = df['text'].str.replace(r'\(bit\.ly/\w+\)', '', regex=True)
# Remove text enclosed in both round and square brackets, including the brackets
df['text'] = df['text'].str.replace(r'\[[^\]]*\]|\([^)]*\)', '', regex=True)
# Remove usernames starting with '@'
df['text'] = df['text'].str.replace(r'@\w+\b', '', regex=True)

# %%
#def cleaning_function(text):
    #removing special characters
 #   clean_1 = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    #This line removes newline characters (\n)
  #  clean_2 = re.sub('\n', '', clean_1)
    #remove words containing digits
  #  clean_3= re.sub('\w*\d\w*', '', clean_2)
    #removing all single characters
  #  clean_4=re.sub(r'\s+[a-zA-Z]\s+', ' ', clean_3)
    #removing all non-alphabetical characters
   # clean_5=re.sub(r'[^a-zA-Z\s]', '', clean_4)
    #remove all white spaces from the text
   # clean_6 = re.sub(r'\s+', ' ', clean_5, flags=re.I)
    #removing contractions
   # clean_7= contractions.fix(clean_6)
    #converting text to lower case
   # clean_8=clean_7.lower()

   # return clean_8
def cleaning_function(text):
    # Remove special characters except punctuation marks
    clean_text = re.sub(r'[^a-zA-Z0-9\s' + re.escape(string.punctuation) + ']', '', text)

    # Remove newline characters
    #clean_text = re.sub('\n', ' ', clean_text)

    # Remove words containing digits
    #clean_text = re.sub(r'\w*\d\w*', '', clean_text)

    # Remove all single characters except punctuation marks
    #clean_text = re.sub(r'\s+[^\w\s' + re.escape(string.punctuation) + ']\s+', ' ', clean_text)

    # Remove all non-alphabetical characters except punctuation marks
    #clean_text = re.sub(r'[^a-zA-Z\s' + re.escape(string.punctuation) + ']', '', clean_text)

    #remove hyperlinks, urls
    clean_text = re.sub('https?://\S+|www\.\S+', '', clean_text)

    # Fix contractions
    clean_text = contractions.fix(clean_text)

    # Remove newline characters
    clean_text = re.sub('\n', ' ', clean_text)

    # Remove words containing digits
    clean_text = re.sub(r'\w*\d\w*', '', clean_text)

    # Remove all single characters except punctuation marks
    clean_text = re.sub(r'\s+[^\w\s' + re.escape(string.punctuation) + ']\s+', ' ', clean_text)
    #removing all punctuation marks except full stop
    clean_text = re.sub(r'[^\w\s.]', '', text)

     # Remove extra whitespaces
    clean_text = re.sub(r'\s+', ' ', clean_text)

    # Convert text to lowercase
    clean_text = clean_text.lower()
    return clean_text

df['title'] = df['title'].apply(cleaning_function)
df['text'] = df['text'].apply(cleaning_function)

# %%
df.head()
# Out:
#                                                title  \
# 0  as u.s. budget fight looms republicans flip th...
# 1  u.s. military to accept transgender recruits o...
# 2  senior u.s. republican senator let mr. mueller...
# 3  fbi russia probe helped by australian diplomat...
# 4  trump wants postal service to charge much more...
#
#                                                 text  label
# 0   the head of a conservative republican faction...      1
# 1   people will be for the first time to enlist i...      1
# 2   the special counsel investigation of links be...      1
# 3   trump campaign adviser told an diplomat in ma...      1
# 4   president trump on the u . s . postal service...      1

# %%
df['text'][28000]
# Out:
# 'just made an amazing stand against bigotry on the by firing one of it s top name for being anti . curt schilling just got handed his pink slip . schilling worked for the network since 2010 and is one of baseball s best known and . but recently schilling decided to share a post in support of an bill in north . the post of an image a man in a wig his t shirt cut to expose and a bizarre black outfit of s clothing . the image was by text which read let him in to the with your daughter or else you re a narrow minded unloving racist bigot who needs to die . former player schilling then added a man is a man no matter what they call themselves . i don t care what they are who they sleep with men s room was designed for the penis s not so much . now you need telling us differently pathetic . later a statement schilling s unacceptable conduct their policy of inclusiveness is an inclusive company . curt schilling been advised that his conduct was unacceptable and his employment with been . of course for those in conservative this was another attack of political correctness which from their of free speech . according to at the daily caller schilling s firing was part of some exodus of conservative media the former red pitcher been very open about his conservative in the past . he was previously suspended by for to the . might have no problem getting rid of conservative but the network extreme liberal in the past without firing anybody . employee tony the tea party to and the tea party was to establish a caliphate . is still pay from . what leaves out is that the tea party is a billionaire backed political movement with the express goal of a theocracy in the united that is federal and state law based on law . on top of this the vast majority of domestic terrorism in the us comes from white and . these have people for being gay who have non whites and non . it is entirely comparable . however a caricature of a cross dresser to invoke fear about people the gender identity appropriate bathroom is plain bigotry . one could just as readily argue the opposite as did en masse with the the . bearded posted of themselves in the s bathroom next to entering and doing their . from posted the picture below do i look like i belong in a s bathroom under the north law would be legally to use the s despite the fact that he would clearly cause some degree of confusion and worry by doing so . surely the long term answer is to remove the gender apartheid from altogether plenty of around the world do just fine mixed . why not us featured image via twitter '

# %%
df['title'][28000]
# Out:
# ' espn just fired curt schilling for this despicable facebook post image'

# %%
def count_stopwords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    stopwords_x = [w for w in word_tokens if w in stop_words]

    return len(stopwords_x)

count_title_sw = (df['title'].apply(count_stopwords))
count_text_sw = (df['text'].apply(count_stopwords))

total_sw_title=count_title_sw.sum()
total_sw_text=count_text_sw.sum()

# %%
print("the number of stopwords in title columns are: ",total_sw_title)
print("the number of stopwords in text columns are: ",total_sw_title)
# Out:
# the number of stopwords in title columns are:  134214
# the number of stopwords in text columns are:  134214

# %%
#count number of sentences
def count_sentences(text):
    sentences = nltk.sent_tokenize(text)
    return len(sentences)

# %%
dataset=df[['title','text','label']].copy()
dataset.columns=['title','text','label']

# %%
dataset['count_title_sentences'] = (df['title'].apply(count_sentences))
dataset['count_text_sentences'] = (df['text'].apply(count_sentences))

# %%
dataset['title_word_count'] = dataset['title'].apply(lambda x : len(x.split()))
dataset['text_word_count'] = dataset['text'].apply(lambda x : len(x.split()))

# %%
dataset['title_char_count'] = dataset['title'].apply(lambda x : len(x.replace(" ","")))
dataset['text_char_count'] = dataset['text'].apply(lambda x : len(x.replace(" ","")))

# %%
dataset['title_word_density'] = dataset['title_word_count'] / (dataset['title_char_count'] + 1)
dataset['text_word_density'] = dataset['text_word_count'] / (dataset['text_char_count'] + 1)

# %%
dataset['title_sent_density'] = dataset['count_title_sentences'] / (dataset['title_word_count'] + 1)
dataset['text_sent_density'] = dataset['count_text_sentences'] / (dataset['text_word_count'] + 1)

# %%
dataset['title_stopw_count'] =  dataset['title'].apply(lambda x : count_stopwords(x))
dataset['text_stopw_count'] =  dataset['text'].apply(lambda x : count_stopwords(x))
dataset['title_stopw_density'] = dataset['title_stopw_count'] / (dataset['title_word_count'] + 1)
dataset['text_stopw_density'] = dataset['text_stopw_count'] / (dataset['text_word_count'] + 1)

# %%
print(dataset[['title_word_count', 'title_char_count', 'title_word_density']].head(5))
print(dataset[['text_word_count', 'text_char_count', 'text_word_density']].head(5))
print(dataset[['count_title_sentences', 'count_text_sentences','text_sent_density','title_sent_density']].head(5))
print(dataset[['title_stopw_count', 'text_stopw_count', 'title_stopw_density', 'text_stopw_density']].head(5))
# Out:
#    title_word_count  title_char_count  title_word_density
# 0                10                54            0.181818
# 1                 9                55            0.160714
# 2                10                48            0.204082
# 3                 9                49            0.180000
# 4                11                57            0.189655
#    text_word_count  text_char_count  text_word_density
# 0              678             2896           0.234035
# 1              543             2371           0.228921
# 2              423             1810           0.233573
# 3              327             1442           0.226611
# 4              775             3222           0.240459
#    count_title_sentences  count_text_sentences  text_sent_density  \
# 0                      1                    40           0.058910
# 1                      1                    37           0.068015
# 2                      1                    22           0.051887
# 3                      1                    21           0.064024
# 4                      1                    55           0.070876
#
#    title_sent_density
# 0            0.090909
# 1            0.100000
# 2            0.090909
# 3            0.100000
# 4            0.083333
#    title_stopw_count  text_stopw_count  title_stopw_density  \
# 0                  2               302             0.181818
# 1                  2               250             0.200000
# 2                  2               200             0.181818
# 3                  1               151             0.100000
# 4                  3               338             0.250000
#
#    text_stopw_density
# 0            0.444772
# 1            0.459559
# 2            0.471698
# 3            0.460366
# 4            0.435567

# %%
dataset[['count_text_sentences', 'text_word_count', 'text_char_count', 'text_stopw_count']].describe()
# Out:
#        count_text_sentences  text_word_count  text_char_count  \
# count          44689.000000     44689.000000     44689.000000
# mean              20.895948       359.009689      1489.281859
# std               17.721471       311.267923      1318.670268
# min                0.000000         0.000000         0.000000
# 25%               10.000000       176.000000       732.000000
# 50%               18.000000       322.000000      1328.000000
# 75%               27.000000       457.000000      1879.000000
# max              375.000000      6858.000000     30284.000000
#
#        text_stopw_count
# count      44689.000000
# mean         172.358567
# std          151.501382
# min            0.000000
# 25%           82.000000
# 50%          154.000000
# 75%          222.000000
# max         3170.000000

# %%
plt.subplots_adjust(hspace=0.5)
plt.subplots_adjust(wspace=0.4)

boxprops1 = dict(facecolor='lightblue')
boxprops2 = dict(facecolor='green')

plt.subplot(2,3,1)
plt.boxplot(dataset['text_word_count'],patch_artist=True, boxprops=boxprops1 )
plt.ylabel("Count")
plt.title("Word Count of text")

plt.subplot(2,3,2)
plt.boxplot(dataset['count_text_sentences'],patch_artist=True, boxprops=boxprops1)
plt.ylabel("Count")
plt.title("Sentence Count of Text")

plt.subplot(2,3,3)
plt.boxplot(dataset['text_char_count'],patch_artist=True, boxprops=boxprops1)
plt.ylabel("Count")
plt.title("Character Count of text")

plt.subplot(2,3,4)
plt.boxplot(dataset['text_word_density'],patch_artist=True, boxprops=boxprops2)
plt.ylabel("Density Ratio")
plt.title("Word Density of text")

plt.subplot(2,3,6)
plt.boxplot(dataset['text_sent_density'],patch_artist=True, boxprops=boxprops2)
plt.ylabel("Density Ratio")
plt.title("Sentence Density of text")



plt.show()

# %%
plt.subplots_adjust(hspace=0.5)
plt.subplots_adjust(wspace=0.4)

plt.subplot(2,3,1)
plt.hist(dataset['text_word_count'])
plt.title("Word Count of text")

plt.subplot(2,3,2)
plt.hist(dataset['count_text_sentences'])
plt.title("Sentence Count of text")

plt.subplot(2,3,3)
plt.hist(dataset['text_char_count'])
plt.title("Character Count of text")

plt.subplot(2,3,4)
plt.hist(dataset['text_word_density'])
plt.title("Word Density of text")

plt.subplot(2,3,6)
plt.hist(dataset['text_sent_density'])
plt.title("Sentence Density of text")



plt.show()

# %%
blob = TextBlob(str(dataset['text']))
pos_df = pd.DataFrame(blob.tags, columns = ['word', 'pos'])
pos_df = pos_df.pos.value_counts()[:30]
pos_df.plot(kind='bar',
            xlabel = "Part Of Speech",
           ylabel = "Frequency",
           title = "Bar Chart of the Frequency of the Parts of Speech in Note",
           figsize=(10, 6))
# Out:
# <Axes: title={'center': 'Bar Chart of the Frequency of the Parts of Speech in Note'}, xlabel='Part Of Speech', ylabel='Frequency'>

# %%
# Removing extra spaces
df['text']=df['text'].apply(lambda x: re.sub(' +',' ',x))

# %%
df['title']=df['title'].apply(lambda x: re.sub(' +',' ',x))

# %%
# Convert lists to strings in the 'title' column
df['title'] = df['title'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)

# Tokenize the 'title' column
df['title'] = df['title'].apply(word_tokenize)

# Remove stop words from the 'title' column
stop_words = set(stopwords.words('english'))
df['title'] = df['title'].apply(lambda x: [word for word in x if word.lower() not in stop_words])

# %%
# Convert lists to strings in the 'title' column
df['text'] = df['text'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)

# Tokenize the 'title' column
df['text'] = df['text'].apply(word_tokenize)

# Remove stop words from the 'title' column
stop_words = set(stopwords.words('english'))
df['text'] = df['text'].apply(lambda x: [word for word in x if word.lower() not in stop_words])

# %%
def remove_punctuations(tokens):
    punctuation_set = set(string.punctuation)

    cleaned_tokens = [token for token in tokens if token not in punctuation_set]

    return cleaned_tokens

df['title'] = df['title'].apply(remove_punctuations)
df['text'] = df['text'].apply(remove_punctuations)

# %%
#lemmatizer = WordNetLemmatizer()
#df['title'] = df['title'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
#df['text'] = df['text'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])

# %%
df['text'][0]
# Out:
# ['head',
#  'conservative',
#  'republican',
#  'faction',
#  'u',
#  'congress',
#  'month',
#  'huge',
#  'expansion',
#  'national',
#  'debt',
#  'pay',
#  'tax',
#  'fiscal',
#  'conservative',
#  'budget',
#  'restraint',
#  '2018',
#  'keeping',
#  'sharp',
#  'pivot',
#  'way',
#  'among',
#  'u',
#  'representative',
#  'mark',
#  'speaking',
#  'face',
#  'nation',
#  'drew',
#  'hard',
#  'line',
#  'federal',
#  'spending',
#  'bracing',
#  'battle',
#  'return',
#  'begin',
#  'trying',
#  'pass',
#  'federal',
#  'budget',
#  'fight',
#  'likely',
#  'linked',
#  'immigration',
#  'policy',
#  'even',
#  'congressional',
#  'election',
#  'approach',
#  'seek',
#  'keep',
#  'control',
#  'congress',
#  'president',
#  'trump',
#  'want',
#  'big',
#  'budget',
#  'increase',
#  'military',
#  'spending',
#  'also',
#  'want',
#  'proportional',
#  'non',
#  'defense',
#  'discretionary',
#  'spending',
#  'support',
#  'education',
#  'scientific',
#  'research',
#  'infrastructure',
#  'public',
#  'health',
#  'environmental',
#  'protection',
#  'administration',
#  'already',
#  'willing',
#  'say',
#  'going',
#  'increase',
#  'non',
#  'defense',
#  'discretionary',
#  'spending',
#  '...',
#  '7',
#  'percent',
#  'chairman',
#  'small',
#  'influential',
#  'house',
#  'freedom',
#  'caucus',
#  'said',
#  'program',
#  'saying',
#  'enough',
#  'need',
#  'give',
#  'government',
#  'pay',
#  'raise',
#  '10',
#  '11',
#  'percent',
#  'fiscal',
#  'conservative',
#  'see',
#  'rationale',
#  '...',
#  'eventually',
#  'run',
#  'people',
#  'money',
#  'said',
#  'among',
#  'late',
#  'party',
#  'debt',
#  'tax',
#  'overhaul',
#  'balloon',
#  'federal',
#  'budget',
#  'deficit',
#  'add',
#  '1',
#  '5',
#  'trillion',
#  '10',
#  '20',
#  'trillion',
#  'national',
#  'debt',
#  'interesting',
#  'hear',
#  'mark',
#  'talk',
#  'fiscal',
#  'responsibility',
#  'democratic',
#  'u',
#  'representative',
#  'said',
#  'said',
#  'republican',
#  'tax',
#  'bill',
#  'would',
#  'require',
#  'united',
#  'borrow',
#  '1',
#  '5',
#  'trillion',
#  'future',
#  'finance',
#  'tax',
#  'rich',
#  'one',
#  'least',
#  '...',
#  'fiscally',
#  'responsible',
#  'ever',
#  'seen',
#  'history',
#  'house',
#  'think',
#  'going',
#  'paying',
#  'many',
#  'many',
#  'come',
#  'said',
#  'insist',
#  'tax',
#  'package',
#  'biggest',
#  'u',
#  'tax',
#  'overhaul',
#  '30',
#  'boost',
#  'economy',
#  'job',
#  'growth',
#  'house',
#  'speaker',
#  'also',
#  'tax',
#  'bill',
#  'recently',
#  'went',
#  'making',
#  'clear',
#  'radio',
#  'interview',
#  'welfare',
#  'entitlement',
#  'reform',
#  'party',
#  'often',
#  'would',
#  'top',
#  'republican',
#  'priority',
#  '2018',
#  'republican',
#  'parlance',
#  'entitlement',
#  'mean',
#  'food',
#  'housing',
#  'assistance',
#  'health',
#  'insurance',
#  'elderly',
#  'poor',
#  'disabled',
#  'well',
#  'assist',
#  'needy',
#  'early',
#  'saying',
#  'would',
#  'try',
#  'pay',
#  'tax',
#  'overhaul',
#  'seeking',
#  'spending',
#  'social',
#  'house',
#  'may',
#  'take',
#  'back',
#  'seat',
#  'senate',
#  'approve',
#  'budget',
#  'prevent',
#  'government',
#  'shutdown',
#  'use',
#  'leverage',
#  'senate',
#  'narrowly',
#  'control',
#  'defend',
#  'discretionary',
#  'non',
#  'defense',
#  'social',
#  'spending',
#  'tackling',
#  'issue',
#  'people',
#  'brought',
#  'illegally',
#  'country',
#  'trump',
#  'put',
#  'march',
#  '2018',
#  'expiration',
#  'date',
#  'deferred',
#  'action',
#  'childhood',
#  'program',
#  'young',
#  'deportation',
#  'work',
#  'president',
#  'said',
#  'recent',
#  'twitter',
#  'border',
#  'wall',
#  'immigration',
#  'law',
#  'exchange',
#  'agreeing',
#  'help',
#  'representative',
#  'told',
#  'favor',
#  'linking',
#  'issue',
#  'policy',
#  'wall',
#  'need',
#  'clean',
#  'said',
#  'trump',
#  'meet',
#  'congressional',
#  'discuss',
#  'weekend',
#  'strategy',
#  'sessions',
#  'trump',
#  'republican',
#  '6',
#  '7',
#  'white',
#  'house',
#  'said',
#  'trump',
#  'also',
#  'meet',
#  'republican',
#  'governor',
#  'rick',
#  'emergency',
#  'aid',
#  'house',
#  '81',
#  'billion',
#  'aid',
#  'package',
#  'package',
#  'far',
#  '44',
#  'billion',
#  'trump',
#  'administration',
#  'senate',
#  'yet',
#  'aid']

# %%
all_tokens = [token for tokens in df['text'] for token in tokens]

freq_dist = FreqDist(all_tokens)

most_common_words = freq_dist.most_common()

for word, frequency in most_common_words:
    print(f"Word: {word}, Frequency: {frequency}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Word: fearlessness, Frequency: 1
# Word: burse, Frequency: 1
# Word: g2x2oyte8p, Frequency: 1
# Word: ym, Frequency: 1
# Word: evrbvigdv9, Frequency: 1
# Word: soapbox, Frequency: 1
# Word: bfl30oct2h, Frequency: 1
# Word: n3lykbkln7, Frequency: 1
# Word: f2ad7fs141, Frequency: 1
# Word: tscwqe62a4, Frequency: 1
# Word: agzdpqpew7, Frequency: 1
# Word: vi4g2tkang, Frequency: 1
# Word: 2016doubtful, Frequency: 1
# Word: 2016nugent, Frequency: 1
# Word: ltrl9wiv26, Frequency: 1
# Word: idkt1gwemf, Frequency: 1
# Word: 2016nonetheless, Frequency: 1
# Word: bmqqx9erzw, Frequency: 1
# Word: catchword, Frequency: 1
# Word: n8efaqdhnt, Frequency: 1
# Word: oom3hsdws1, Frequency: 1
# Word: 6qxxcticbr, Frequency: 1
# Word: parker9_, Frequency: 1
# Word: unhuman, Frequency: 1
# Word: z6kkgt5hk6, Frequency: 1
# Word: babyish, Frequency: 1
# Word: puerile, Frequency: 1
# Word: exrjn04qij, Frequency: 1
# Word: mmdkdqqdh5, Frequency: 1
# Word: hspickering1, Frequency: 1
# Word: uj5pr2qocj, Frequency: 1
# Word: mathiasb26, Frequency: 1
# Word: whkdsn8ogc, Frequency: 1
# Word: jbristol11, Frequency: 1
# Word: b2, Frequency: 1
# Word: hypnotism, Frequency: 1
# Word: pallor, Frequency: 1
# Word: toga, Frequency: 1
# Word: misapply, Frequency: 1
# Word: up3y963ssr, Frequency: 1
# Word: 2016starbucks, Frequency: 1
# Word: ruofj4ed3b, Frequency: 1
# Word: 4ymcjtdqbi, Frequency: 1
# Word: fb1ytfsomo, Frequency: 1
# Word: of583sse8e, Frequency: 1
# Word: lhbikw1elr, Frequency: 1
# Word: c6ocus52uy, Frequency: 1
# Word: mr4ibcga9h, Frequency: 1
# Word: 21kgtppmzk, Frequency: 1
# Word: y4nz3arsmg, Frequency: 1
# Word: u1l3dibs2q, Frequency: 1
# Word: iz4nirs2qh, Frequency: 1
# Word: o8vorbe1d9, Frequency: 1
# Word: _targetsmart, Frequency: 1
# Word: 40early, Frequency: 1
# Word: 38likely, Frequency: 1
# Word: 2016tom, Frequency: 1
# Word: znik7ueyee, Frequency: 1
# Word: 7szi2z552u, Frequency: 1
# Word: zkxseo5fei, Frequency: 1
# Word: i46k3xearh, Frequency: 1
# Word: hbqw1uvsfj, Frequency: 1
# Word: 4sc6vtu80c, Frequency: 1
# Word: 2016hellooooooooooooooooo, Frequency: 1
# Word: ewfyfedfx9, Frequency: 1
# Word: kp6kvpntmo, Frequency: 1
# Word: nefariously, Frequency: 1
# Word: 0pbruepg1o, Frequency: 1
# Word: unspeakably, Frequency: 1
# Word: kmkxkwncv3, Frequency: 1
# Word: mk_rodgers, Frequency: 1
# Word: xv1uxmofaw, Frequency: 1
# Word: 2016mccausland, Frequency: 1
# Word: 2yqga6dd4k, Frequency: 1
# Word: uwexp4vkyx, Frequency: 1
# Word: 2016pete, Frequency: 1
# Word: lgjho3xlem, Frequency: 1
# Word: padding, Frequency: 1
# Word: quickness, Frequency: 1
# Word: 92pgkesgmb, Frequency: 1
# Word: 2016journalism, Frequency: 1
# Word: 50zbotvfhy, Frequency: 1
# Word: fj1zcsael4, Frequency: 1
# Word: b3ttdsdenp, Frequency: 1
# Word: defensiveness, Frequency: 1
# Word: 288th, Frequency: 1
# Word: 335th, Frequency: 1
# Word: dubsteps4dads, Frequency: 1
# Word: eh48ixb3np, Frequency: 1
# Word: epca13ezfo, Frequency: 1
# Word: 2016stephanopoulos, Frequency: 1
# Word: 2016bulgaria, Frequency: 1
# Word: 2016among, Frequency: 1
# Word: eyeful, Frequency: 1
# Word: 5ce8szw5mh, Frequency: 1
# Word: qz3x1er8j0, Frequency: 1
# Word: u922sh1j7g, Frequency: 1
# Word: 2016ivanka, Frequency: 1
# Word: 3apjqmgg1k, Frequency: 1
# Word: tj800, Frequency: 1
# Word: 4mac1ddybc, Frequency: 1
# Word: dr_conzelmann, Frequency: 1
# Word: gaunt, Frequency: 1
# Word: ttvvmuz4mm, Frequency: 1
# Word: sct8gpcfjr, Frequency: 1
# Word: mcmullinfinn2016, Frequency: 1
# Word: 2016stephen, Frequency: 1
# Word: unendorsed, Frequency: 1
# Word: 4cejnnskdo, Frequency: 1
# Word: 9rp9sekx1c, Frequency: 1
# Word: 2016knowing, Frequency: 1
# Word: 71jhlg55g5, Frequency: 1
# Word: k1gucas64r, Frequency: 1
# Word: _maryali, Frequency: 1
# Word: xaibt9wvqo, Frequency: 1
# Word: 2016cleese, Frequency: 1
# Word: lhocooupq3, Frequency: 1
# Word: 2015fascinating, Frequency: 1
# Word: ridiculosity, Frequency: 1
# Word: psychiatrically, Frequency: 1
# Word: q2gvpagq9p, Frequency: 1
# Word: bloodthirstiness, Frequency: 1
# Word: ryanwilliams97, Frequency: 1
# Word: 43pm, Frequency: 1
# Word: 9effzgimcx, Frequency: 1
# Word: 1234, Frequency: 1
# Word: lonesome, Frequency: 1
# Word: nary, Frequency: 1
# Word: raindrop, Frequency: 1
# Word: 2rr56reogyk, Frequency: 1
# Word: npzh1avcsz, Frequency: 1
# Word: 2kn2suupde, Frequency: 1
# Word: 2016gotta, Frequency: 1
# Word: womankind, Frequency: 1
# Word: idm7n1ioh5, Frequency: 1
# Word: 0umzbrgmw5, Frequency: 1
# Word: 7uxzme2okh, Frequency: 1
# Word: fzjiw8pxng, Frequency: 1
# Word: retriever, Frequency: 1
# Word: wkeqs6tmu8, Frequency: 1
# Word: 2016judging, Frequency: 1
# Word: fcl9sgxhp3, Frequency: 1
# Word: lepytc2sx5, Frequency: 1
# Word: fractiousness, Frequency: 1
# Word: pdo0nl2pcp, Frequency: 1
# Word: 2016klempko, Frequency: 1
# Word: kcmsis94gm, Frequency: 1
# Word: moneygrubber, Frequency: 1
# Word: tattle, Frequency: 1
# Word: als0, Frequency: 1
# Word: hawthorn, Frequency: 1
# Word: lllbblzba5, Frequency: 1
# Word: plat, Frequency: 1
# Word: drhyf0pxwc, Frequency: 1
# Word: qrf14u8npd, Frequency: 1
# Word: lodcjq8wqy, Frequency: 1
# Word: viirzh1wry, Frequency: 1
# Word: 5bpefsfhvi, Frequency: 1
# Word: pv6dvzsydj, Frequency: 1
# Word: sgnr75wc1o, Frequency: 1
# Word: xhe9k5f7xt, Frequency: 1
# Word: 2016tyson, Frequency: 1
# Word: yyky8vfmp5, Frequency: 1
# Word: ot9sxnk7dk, Frequency: 1
# Word: abscessed, Frequency: 1
# Word: dvmuczbo31, Frequency: 1
# Word: qttbk9one0, Frequency: 1
# Word: 37yrs, Frequency: 1
# Word: vesuvius, Frequency: 1
# Word: evilness, Frequency: 1
# Word: mkrbh47duo, Frequency: 1
# Word: myeloid, Frequency: 1
# Word: eb4nepxp2g, Frequency: 1
# Word: ij4rkycp3p, Frequency: 1
# Word: uk6af3gjji, Frequency: 1
# Word: d1kz95gpse, Frequency: 1
# Word: lh7cijiuks, Frequency: 1
# Word: wph3higga0, Frequency: 1
# Word: mjfgbzq3iv, Frequency: 1
# Word: 4azbliptfr, Frequency: 1
# Word: dl945, Frequency: 1
# Word: poignantly, Frequency: 1
# Word: scribble, Frequency: 1
# Word: deplorability, Frequency: 1
# Word: cristinalaila1, Frequency: 1
# Word: 26days, Frequency: 1
# Word: naw, Frequency: 1
# Word: 2016warning, Frequency: 1
# Word: e7ccg35dqz, Frequency: 1
# Word: h6aaxakdek, Frequency: 1
# Word: 2015seems, Frequency: 1
# Word: 2015conservatives, Frequency: 1
# Word: 1ljaiv8wvl, Frequency: 1
# Word: mkimxidr3z, Frequency: 1
# Word: pdxgl5nqhd, Frequency: 1
# Word: monogamy, Frequency: 1
# Word: o9u6rp3ash, Frequency: 1
# Word: underhand, Frequency: 1
# Word: kcwtelmc3c, Frequency: 1
# Word: 51pn40hzpq, Frequency: 1
# Word: gbwomm7tga, Frequency: 1
# Word: htm9uaesne, Frequency: 1
# Word: doltishness, Frequency: 1
# Word: w2zch6sdr1, Frequency: 1
# Word: hjqjzivwc4, Frequency: 1
# Word: repealthe19thhere, Frequency: 1
# Word: jnnxavxix1, Frequency: 1
# Word: 2016female, Frequency: 1
# Word: harpooner, Frequency: 1
# Word: 2016repeal, Frequency: 1
# Word: qqvd3qre7o, Frequency: 1
# Word: dvn5rr43qk, Frequency: 1
# Word: gent, Frequency: 1
# Word: 2016give, Frequency: 1
# Word: bv4wnbgq2h, Frequency: 1
# Word: natesilver538, Frequency: 1
# Word: bells8911, Frequency: 1
# Word: 13300472, Frequency: 1
# Word: foolhardiness, Frequency: 1
# Word: markrosner3, Frequency: 1
# Word: 2016newsflash, Frequency: 1
# Word: o4qqf8stlt, Frequency: 1
# Word: 7ogxvkqdma, Frequency: 1
# Word: spycirtyc9, Frequency: 1
# Word: 4ctf1fp6ej, Frequency: 1
# Word: 2016shame, Frequency: 1
# Word: djhywrb2ed, Frequency: 1
# Word: 2016guys, Frequency: 1
# Word: irb09cq8eh, Frequency: 1
# Word: iynueqow64, Frequency: 1
# Word: 2016gesing, Frequency: 1
# Word: ghbjx17w9c, Frequency: 1
# Word: blacking, Frequency: 1
# Word: vq1awilbfs, Frequency: 1
# Word: xwbcxjycf1, Frequency: 1
# Word: 2016twitterby, Frequency: 1
# Word: ulsp9xjg7f, Frequency: 1
# Word: elxq6cheuv, Frequency: 1
# Word: p5orjbgw55, Frequency: 1
# Word: 2016jeff, Frequency: 1
# Word: 2016various, Frequency: 1
# Word: 2016actual, Frequency: 1
# Word: 2016attached, Frequency: 1
# Word: 2016cc, Frequency: 1
# Word: 2016disloyal, Frequency: 1
# Word: piggish, Frequency: 1
# Word: kjd0kfmosa, Frequency: 1
# Word: pugilist, Frequency: 1
# Word: erej5pkhnc, Frequency: 1
# Word: unliked, Frequency: 1
# Word: caxu9zbvre, Frequency: 1
# Word: letch, Frequency: 1
# Word: chine, Frequency: 1
# Word: eclecticism, Frequency: 1
# Word: vq0lpqp7nw, Frequency: 1
# Word: mirthful, Frequency: 1
# Word: rlmbtt5wwy, Frequency: 1
# Word: ismjvhhl1k, Frequency: 1
# Word: dw6rrs4ze8, Frequency: 1
# Word: ifk1tuwaix, Frequency: 1
# Word: ywgqq12lhg, Frequency: 1
# Word: 2016ross, Frequency: 1
# Word: t7lolmmh2s, Frequency: 1
# Word: 2016oral, Frequency: 1
# Word: pannv2qp1n, Frequency: 1
# Word: pdoj5esdzw, Frequency: 1
# Word: bo45r4a0ma, Frequency: 1
# Word: uvdeth4moq, Frequency: 1
# Word: uvxsdzkl13, Frequency: 1
# Word: e8ua9f7thn, Frequency: 1
# Word: concubine, Frequency: 1
# Word: maul, Frequency: 1
# Word: cutaway, Frequency: 1
# Word: 2jl40jdolf, Frequency: 1
# Word: 16btqywspr, Frequency: 1
# Word: ip29jnouks, Frequency: 1
# Word: mutt, Frequency: 1
# Word: jgv5rujzib, Frequency: 1
# Word: egv2ccmsio, Frequency: 1
# Word: bigstick2013, Frequency: 1
# Word: sorrowfully, Frequency: 1
# Word: fgcrzeo6er, Frequency: 1
# Word: gmarie55, Frequency: 1
# Word: meridian, Frequency: 1
# Word: umy6koistu, Frequency: 1
# Word: pompousness, Frequency: 1
# Word: pompously, Frequency: 1
# Word: utfr8wkome, Frequency: 1
# Word: bosseone2, Frequency: 1
# Word: ixlr8, Frequency: 1
# Word: mouthy, Frequency: 1
# Word: 2016whom, Frequency: 1
# Word: uneasiness, Frequency: 1
# Word: ykscxfzgw7, Frequency: 1
# Word: nptrqynoh3, Frequency: 1
# Word: dftpisw9os, Frequency: 1
# Word: 1jrkkv7g7u, Frequency: 1
# Word: bracketing, Frequency: 1
# Word: 1219, Frequency: 1
# Word: eaveyhtne0, Frequency: 1
# Word: vg62met4v0, Frequency: 1
# Word: sagv2xwq3r, Frequency: 1
# Word: 2016polson, Frequency: 1
# Word: gm29aedxt4, Frequency: 1
# Word: 2016host, Frequency: 1
# Word: 2016things, Frequency: 1
# Word: lainey34210, Frequency: 1
# Word: bigdog_joey, Frequency: 1
# Word: elisac006, Frequency: 1
# Word: jnelson52722, Frequency: 1
# Word: muw9s5ggnm, Frequency: 1
# Word: iczxn7q3vz, Frequency: 1
# Word: qwkvgfara1, Frequency: 1
# Word: 2016caps, Frequency: 1
# Word: xuwauenkh0, Frequency: 1
# Word: qn9qqoq1kh, Frequency: 1
# Word: 2016sanctions, Frequency: 1
# Word: lm80jrif9k, Frequency: 1
# Word: wpym5vqoyt, Frequency: 1
# Word: 2016quick, Frequency: 1
# Word: 8prednmnfx, Frequency: 1
# Word: 2016retweets, Frequency: 1
# Word: gsimmons03ginny, Frequency: 1
# Word: ejaculation, Frequency: 1
# Word: biostatistics, Frequency: 1
# Word: loma, Frequency: 1
# Word: bxne0nqn6m, Frequency: 1
# Word: rv1vclf6ib, Frequency: 1
# Word: boke18, Frequency: 1
# Word: a0bual1uj8, Frequency: 1
# Word: chl2neazii, Frequency: 1
# Word: yklobpee6k, Frequency: 1
# Word: shamer, Frequency: 1
# Word: thermos, Frequency: 1
# Word: we0lnb2lqh, Frequency: 1
# Word: tumbleweed, Frequency: 1
# Word: 2016reagan, Frequency: 1
# Word: ztbmcb3wui, Frequency: 1
# Word: k7p5wdb2cl, Frequency: 1
# Word: spva0gd7uz, Frequency: 1
# Word: vvc2kghskm, Frequency: 1
# Word: mnnbpfy7ov, Frequency: 1
# Word: nokntr8xdx, Frequency: 1
# Word: 2016cowardly, Frequency: 1
# Word: 2016stronger, Frequency: 1
# Word: 2016kardashian, Frequency: 1
# Word: 20pm, Frequency: 1
# Word: nykvqng6nj, Frequency: 1
# Word: 2016upwards, Frequency: 1
# Word: mwkq1f7nvr, Frequency: 1
# Word: 2016cuban, Frequency: 1
# Word: misfile, Frequency: 1
# Word: oligarchical, Frequency: 1
# Word: g62jb9fkr5, Frequency: 1
# Word: ambling, Frequency: 1
# Word: p4ammx10ls, Frequency: 1
# Word: unnerve, Frequency: 1
# Word: c__t, Frequency: 1
# Word: 6hrcc16uiv, Frequency: 1
# Word: 2016prior, Frequency: 1
# Word: lmsmo06yfj, Frequency: 1
# Word: comvs84lcj, Frequency: 1
# Word: wurws6aj5f, Frequency: 1
# Word: 2016alicia, Frequency: 1
# Word: ozv8yg8vjz, Frequency: 1
# Word: captivate, Frequency: 1
# Word: bakula, Frequency: 1
# Word: quinto, Frequency: 1
# Word: 15holm, Frequency: 1
# Word: 2016shortly, Frequency: 1
# Word: mero, Frequency: 1
# Word: xhmfnu9ttr, Frequency: 1
# Word: rotund, Frequency: 1
# Word: 0punwffhwc, Frequency: 1
# Word: nrazppl0q0, Frequency: 1
# Word: undertone, Frequency: 1
# Word: braggart, Frequency: 1
# Word: apricot, Frequency: 1
# Word: xiue9bpc40, Frequency: 1
# Word: ringer, Frequency: 1
# Word: headstrong, Frequency: 1
# Word: qharxkx1zj, Frequency: 1
# Word: lqgeh4hmqe, Frequency: 1
# Word: carsick, Frequency: 1
# Word: plqx1kkpcv, Frequency: 1
# Word: cr2qd45je2, Frequency: 1
# Word: 2016fun, Frequency: 1
# Word: 2016private, Frequency: 1
# Word: nr0ig6xyqv, Frequency: 1
# Word: qg5l5hcnvl, Frequency: 1
# Word: 2016hope, Frequency: 1
# Word: 0kxxsnnmh5, Frequency: 1
# Word: csoon8nf3y, Frequency: 1
# Word: 2016such, Frequency: 1
# Word: 3kwol2ibaw, Frequency: 1
# Word: sfcee3i5pf, Frequency: 1
# Word: avrv9wkg9t, Frequency: 1
# Word: 2016continuing, Frequency: 1
# Word: 780619672760623104, Frequency: 1
# Word: thirstiness, Frequency: 1
# Word: 2016want, Frequency: 1
# Word: axe58zcejl, Frequency: 1
# Word: 2016photo, Frequency: 1
# Word: feathering, Frequency: 1
# Word: phobic, Frequency: 1
# Word: 2016saying, Frequency: 1
# Word: a4rwuhyr5z, Frequency: 1
# Word: watsit2u, Frequency: 1
# Word: athqtwol7e, Frequency: 1
# Word: cwlaa8ugmx, Frequency: 1
# Word: 2016luckey, Frequency: 1
# Word: q6elyd01qv, Frequency: 1
# Word: women4trump, Frequency: 1
# Word: superwoman, Frequency: 1
# Word: nfrqb9szor, Frequency: 1
# Word: 2016mastercard, Frequency: 1
# Word: rkpko68t5v, Frequency: 1
# Word: gdvpp10cvh, Frequency: 1
# Word: gjn6rktamk, Frequency: 1
# Word: dcxn24fan, Frequency: 1
# Word: fox28, Frequency: 1
# Word: buffy, Frequency: 1
# Word: otd8owrcu7, Frequency: 1
# Word: 2016rye, Frequency: 1
# Word: fvy4guzmzu, Frequency: 1
# Word: equivocator, Frequency: 1
# Word: retch, Frequency: 1
# Word: tw0wmvssnm, Frequency: 1
# Word: 2soundoff, Frequency: 1
# Word: wbtv_news, Frequency: 1
# Word: jwhmixy9m7, Frequency: 1
# Word: eventful, Frequency: 1
# Word: 9fhwog7ssn, Frequency: 1
# Word: 86fswdft5o, Frequency: 1
# Word: 2016george, Frequency: 1
# Word: presentment, Frequency: 1
# Word: zvvqnxeiq9, Frequency: 1
# Word: tzgozmcm2z, Frequency: 1
# Word: frosting, Frequency: 1
# Word: keymx7ddrk, Frequency: 1
# Word: u2mkvgvoop, Frequency: 1
# Word: ks2pg5igyc, Frequency: 1
# Word: 3cn20xqwml, Frequency: 1
# Word: 2tggidwndx, Frequency: 1
# Word: icke8gsuco, Frequency: 1
# Word: grouchy, Frequency: 1
# Word: roguish, Frequency: 1
# Word: cartridge, Frequency: 1
# Word: unarmored, Frequency: 1
# Word: 1102167116543853, Frequency: 1
# Word: cx7yt6u08c8featured, Frequency: 1
# Word: 8fglkl3tu5, Frequency: 1
# Word: ineffectively, Frequency: 1
# Word: 0dvb5b0gbc, Frequency: 1
# Word: 2016pows, Frequency: 1
# Word: 6i6wksc4di, Frequency: 1
# Word: 6eza8loaon, Frequency: 1
# Word: mtu7mx9dfc, Frequency: 1
# Word: rh3fblmjjy, Frequency: 1
# Word: aw4q5nj8h8, Frequency: 1
# Word: 2016inside, Frequency: 1
# Word: lmi5mpbkm4, Frequency: 1
# Word: gbhpkt4a2o, Frequency: 1
# Word: r7dhutpg4e, Frequency: 1
# Word: xdiqifrl8m, Frequency: 1
# Word: uypqi3w42l, Frequency: 1
# Word: 32xxb2tgre, Frequency: 1
# Word: taster, Frequency: 1
# Word: neuropathologist, Frequency: 1
# Word: encephalopathy, Frequency: 1
# Word: toxicologic, Frequency: 1
# Word: jtfqbwb00g, Frequency: 1
# Word: 2016creepy, Frequency: 1
# Word: i1sl6gnnsi, Frequency: 1
# Word: 2016excellent, Frequency: 1
# Word: uegd3fbsox, Frequency: 1
# Word: gktyje5km8, Frequency: 1
# Word: qnyjipw9qo, Frequency: 1
# Word: 061, Frequency: 1
# Word: 37b, Frequency: 1
# Word: hymen, Frequency: 1
# Word: blackball, Frequency: 1
# Word: tzms6nrfwi, Frequency: 1
# Word: presto, Frequency: 1
# Word: 4ratings, Frequency: 1
# Word: acma2010, Frequency: 1
# Word: frailty, Frequency: 1
# Word: lhxy2ibln8, Frequency: 1
# Word: 2016cthulhu, Frequency: 1
# Word: aku0pfnog2, Frequency: 1
# Word: sphincter, Frequency: 1
# Word: shafting, Frequency: 1
# Word: kmkcdviar4, Frequency: 1
# Word: agnosticism, Frequency: 1
# Word: retrievable, Frequency: 1
# Word: dumba, Frequency: 1
# Word: mwfdlsxal3, Frequency: 1
# Word: 2016watson, Frequency: 1
# Word: e9orlut4on, Frequency: 1
# Word: u72shiovay, Frequency: 1
# Word: z9qwhxmyes, Frequency: 1
# Word: penuzrzv7f, Frequency: 1
# Word: 2016heh, Frequency: 1
# Word: timidity, Frequency: 1
# Word: glibly, Frequency: 1
# Word: bogart, Frequency: 1
# Word: idrgflxp3a, Frequency: 1
# Word: syncope, Frequency: 1
# Word: ahlat24lvd, Frequency: 1
# Word: jdrmdci3ln, Frequency: 1
# Word: fireproofing, Frequency: 1
# Word: introspective, Frequency: 1
# Word: 0xitb7xejv, Frequency: 1
# Word: if6s05se2w, Frequency: 1
# Word: hubble, Frequency: 1
# Word: opu89omvrh, Frequency: 1
# Word: victoriously, Frequency: 1
# Word: gfevt0kujd, Frequency: 1
# Word: billyt_202, Frequency: 1
# Word: moa8hbfubl, Frequency: 1
# Word: 0ptsejgg6p, Frequency: 1
# Word: 4isjaqjt_vmfeatured, Frequency: 1
# Word: qvrf5yf6ur, Frequency: 1
# Word: craps, Frequency: 1
# Word: 2016jason, Frequency: 1
# Word: inaccessibility, Frequency: 1
# Word: deceitfully, Frequency: 1
# Word: naturalness, Frequency: 1
# Word: 2016kaepernick, Frequency: 1
# Word: mruf4ssyyn, Frequency: 1
# Word: pyn92mesom, Frequency: 1
# Word: a5in7j9s9l, Frequency: 1
# Word: zbqo5raesk, Frequency: 1
# Word: 2016oswalt, Frequency: 1
# Word: 2016shkreli, Frequency: 1
# Word: hprn9j9hms, Frequency: 1
# Word: wlcs83u3e4, Frequency: 1
# Word: dwyvdq4vxh, Frequency: 1
# Word: j0uln9zrrl, Frequency: 1
# Word: ysmcvxiub3, Frequency: 1
# Word: km9a8k0y2g, Frequency: 1
# Word: u31rsfxhtx, Frequency: 1
# Word: 2016ur, Frequency: 1
# Word: jbb2cuog4r, Frequency: 1
# Word: ou6vv4ar1x, Frequency: 1
# Word: zmo9sk2ram, Frequency: 1
# Word: fqmdq25zoi, Frequency: 1
# Word: 2016didn, Frequency: 1
# Word: cryogenics, Frequency: 1
# Word: dh2ddzp72k, Frequency: 1
# Word: kt5tavwrfx, Frequency: 1
# Word: 9kkhiusvpp, Frequency: 1
# Word: conservator, Frequency: 1
# Word: accordion, Frequency: 1
# Word: g4qvqhxlen, Frequency: 1
# Word: ci9iok8dye, Frequency: 1
# Word: g0rkpfajmr, Frequency: 1
# Word: ngxtjotaj9, Frequency: 1
# Word: h31q5vmxvc, Frequency: 1
# Word: mulatto, Frequency: 1
# Word: zeqhohqfa8, Frequency: 1
# Word: peon, Frequency: 1
# Word: kennybor24, Frequency: 1
# Word: 2016contrary, Frequency: 1
# Word: 2d7pyyfmyo, Frequency: 1
# Word: hp4a5te2n2, Frequency: 1
# Word: 15zpelbrkf, Frequency: 1
# Word: l0wobg3qwy, Frequency: 1
# Word: nmymqm2c4a, Frequency: 1
# Word: 1lgqrmjpvs, Frequency: 1
# Word: j7dtaynrsu, Frequency: 1
# Word: 2016moderator, Frequency: 1
# Word: q3m39ldyqy, Frequency: 1
# Word: forcefulness, Frequency: 1
# Word: situate, Frequency: 1
# Word: 772118873231482880, Frequency: 1
# Word: kl1alvukg4, Frequency: 1
# Word: 2016other, Frequency: 1
# Word: insidiously, Frequency: 1
# Word: 0wybx8dosp, Frequency: 1
# Word: 67xufvir1f, Frequency: 1
# Word: eneccvx5mn, Frequency: 1
# Word: nejaqyi3cf, Frequency: 1
# Word: jrz6ibwvye, Frequency: 1
# Word: 2016obligatory, Frequency: 1
# Word: y0kskqhshl, Frequency: 1
# Word: pddetwrei1, Frequency: 1
# Word: 12ckpi6tb4, Frequency: 1
# Word: twerp, Frequency: 1
# Word: ntiufzmqq5, Frequency: 1
# Word: 2016congressman, Frequency: 1
# Word: fhuh4zdfuh, Frequency: 1
# Word: 2016dominating, Frequency: 1
# Word: z44bmf1toq, Frequency: 1
# Word: 9kuz7q4ene, Frequency: 1
# Word: 2016cultural, Frequency: 1
# Word: 2016arizona, Frequency: 1
# Word: compassionately, Frequency: 1
# Word: sdqciimnc1, Frequency: 1
# Word: eetcg5twtv, Frequency: 1
# Word: dialer, Frequency: 1
# Word: zl5vpfbbuq, Frequency: 1
# Word: muskrat, Frequency: 1
# Word: 2016rip, Frequency: 1
# Word: dkx4jdilia, Frequency: 1
# Word: klj0u49pqh, Frequency: 1
# Word: 23pm, Frequency: 1
# Word: aggrievement, Frequency: 1
# Word: 2016translated, Frequency: 1
# Word: 2016alongside, Frequency: 1
# Word: rzfoke45ro, Frequency: 1
# Word: 2016translation, Frequency: 1
# Word: e80tzxqr8m, Frequency: 1
# Word: t54dxz58mn, Frequency: 1
# Word: dpk5sekywg, Frequency: 1
# Word: q5lh26jjed, Frequency: 1
# Word: 6g5pny5usq, Frequency: 1
# Word: 2016overall, Frequency: 1
# Word: wbcipj4p5z, Frequency: 1
# Word: uw9tqwcwzr, Frequency: 1
# Word: yq9erqqov8, Frequency: 1
# Word: 3emih2whwb, Frequency: 1
# Word: clkveh2yp4, Frequency: 1
# Word: 2016katrina, Frequency: 1
# Word: scooper, Frequency: 1
# Word: 769886874580246528featured, Frequency: 1
# Word: hgnb02eoku, Frequency: 1
# Word: 2016kaine, Frequency: 1
# Word: 31dhum8tmg, Frequency: 1
# Word: 114m, Frequency: 1
# Word: 2016organizers, Frequency: 1
# Word: r9ailsnuzh, Frequency: 1
# Word: 2016wade, Frequency: 1
# Word: v5epogiuqy, Frequency: 1
# Word: 7vocnocqpo, Frequency: 1
# Word: yg7c7tqnun, Frequency: 1
# Word: vj0joilc18, Frequency: 1
# Word: impertinence, Frequency: 1
# Word: licorice, Frequency: 1
# Word: scandalously, Frequency: 1
# Word: 636549976507499warren, Frequency: 1
# Word: 2016take, Frequency: 1
# Word: sightly, Frequency: 1
# Word: 9bpocgzuqx, Frequency: 1
# Word: q3p1y7hetg, Frequency: 1
# Word: yayxgftr1r, Frequency: 1
# Word: hex4qijqdg, Frequency: 1
# Word: 690imjnbom, Frequency: 1
# Word: ajbon3tcdp, Frequency: 1
# Word: bor8fmitnz, Frequency: 1
# Word: rewire, Frequency: 1
# Word: quart, Frequency: 1
# Word: tongs, Frequency: 1
# Word: dishwashing, Frequency: 1
# Word: menopause, Frequency: 1
# Word: motorboat, Frequency: 1
# Word: 971933766252421, Frequency: 1
# Word: rb3lodtgtv, Frequency: 1
# Word: scatological, Frequency: 1
# Word: snugly, Frequency: 1
# Word: rio2016, Frequency: 1
# Word: tdbt0y5acx, Frequency: 1
# Word: ksqzp17drc, Frequency: 1
# Word: woundwort, Frequency: 1
# Word: 5nlra9o5l7, Frequency: 1
# Word: iygf8vukkv, Frequency: 1
# Word: b1q6lxaivf, Frequency: 1
# Word: yjukzqw8bz, Frequency: 1
# Word: jnjldu4elu, Frequency: 1
# Word: bream, Frequency: 1
# Word: wfdrw5qhyi, Frequency: 1
# Word: applcec4rtufeatured, Frequency: 1
# Word: rtuwnlmtt3, Frequency: 1
# Word: stands4, Frequency: 1
# Word: nvsqnx6py0, Frequency: 1
# Word: 2make, Frequency: 1
# Word: q_state_fun, Frequency: 1
# Word: 2go, Frequency: 1
# Word: some1, Frequency: 1
# Word: pixccm39xj, Frequency: 1
# Word: zb0lwwx5mg, Frequency: 1
# Word: underprice, Frequency: 1
# Word: sfwbd3oud7, Frequency: 1
# Word: na9nxhsgeg, Frequency: 1
# Word: wpsy8zpmzd, Frequency: 1
# Word: bwwr8gfeqt, Frequency: 1
# Word: mf8jqu6isf, Frequency: 1
# Word: zbvvan4s86, Frequency: 1
# Word: cldd4qkgyi, Frequency: 1
# Word: hrb03msy0g, Frequency: 1
# Word: ucyzaxztm7, Frequency: 1
# Word: duke7045, Frequency: 1
# Word: fearss33, Frequency: 1
# Word: roxy, Frequency: 1
# Word: 65ot7sdqs6, Frequency: 1
# Word: 8scxocwjfr, Frequency: 1
# Word: discontinuation, Frequency: 1
# Word: disproportionally, Frequency: 1
# Word: fresnel, Frequency: 1
# Word: jvwpm42lgm, Frequency: 1
# Word: looter, Frequency: 1
# Word: drunkard, Frequency: 1
# Word: 72hr, Frequency: 1
# Word: f6strwfeatured, Frequency: 1
# Word: 5trwbjcgyr, Frequency: 1
# Word: ojk77dpovl, Frequency: 1
# Word: rootless, Frequency: 1
# Word: h04wanqiub, Frequency: 1
# Word: insensible, Frequency: 1
# Word: z5zofqt217, Frequency: 1
# Word: 05hq5zuroy, Frequency: 1
# Word: 3tc1infzj0, Frequency: 1
# Word: tv8vtibcgv, Frequency: 1
# Word: playfulness, Frequency: 1
# Word: lpqj34kaor, Frequency: 1
# Word: lifeboat, Frequency: 1
# Word: floater, Frequency: 1
# Word: 7bh7iihhay, Frequency: 1
# Word: 5ktusihbx1, Frequency: 1
# Word: evan_mcmullin, Frequency: 1
# Word: hfwtipadk6, Frequency: 1
# Word: atsgy3b9mqwfeatured, Frequency: 1
# Word: arthel, Frequency: 1
# Word: muffin, Frequency: 1
# Word: 8himytr0, Frequency: 1
# Word: 4mfeatured, Frequency: 1
# Word: vri2oz0epu, Frequency: 1
# Word: alala, Frequency: 1
# Word: ggoawcep6y, Frequency: 1
# Word: glom, Frequency: 1
# Word: jgkndxluy6, Frequency: 1
# Word: rosier, Frequency: 1
# Word: reasonability, Frequency: 1
# Word: 4fhelne7ah, Frequency: 1
# Word: jgzmskm9cf, Frequency: 1
# Word: 2016brannigan, Frequency: 1
# Word: cfq1rq4vey, Frequency: 1
# Word: sectional, Frequency: 1
# Word: submersion, Frequency: 1
# Word: p8exlfgvtl, Frequency: 1
# Word: haberdasher, Frequency: 1
# Word: pussyfooting, Frequency: 1
# Word: nxe6gutz4h, Frequency: 1
# Word: u6wayvbo75, Frequency: 1
# Word: sidewise, Frequency: 1
# Word: 727s, Frequency: 1
# Word: stumpy, Frequency: 1
# Word: 1tn, Frequency: 1
# Word: diagnosable, Frequency: 1
# Word: gfniw6aphx, Frequency: 1
# Word: 5vd9x3qmxy, Frequency: 1
# Word: 2vfqpks3ld, Frequency: 1
# Word: qm6abzwzlo, Frequency: 1
# Word: bqqzfkigi6, Frequency: 1
# Word: griega1953, Frequency: 1
# Word: jxjf60cjot, Frequency: 1
# Word: ql3ghvns47, Frequency: 1
# Word: p3idcg2jlk, Frequency: 1
# Word: il8iqx6eym, Frequency: 1
# Word: unnb5u7i4r, Frequency: 1
# Word: viol, Frequency: 1
# Word: ol8olddsaq, Frequency: 1
# Word: clarknt67, Frequency: 1
# Word: kme1wpkdix, Frequency: 1
# Word: 8aptu2w2dz, Frequency: 1
# Word: nr6hqwlmm0, Frequency: 1
# Word: msj79eka5q, Frequency: 1
# Word: pfbwk1p7l5, Frequency: 1
# Word: linguist, Frequency: 1
# Word: 2016classic, Frequency: 1
# Word: stilted, Frequency: 1
# Word: impetuously, Frequency: 1
# Word: 2016zerohedge, Frequency: 1
# Word: declination, Frequency: 1
# Word: u2dclsluyx8featured, Frequency: 1
# Word: byezquz9uyafeatured, Frequency: 1
# Word: 5xorzzkdxq, Frequency: 1
# Word: 5xorzzbpmq, Frequency: 1
# Word: 201659, Frequency: 1
# Word: 9px2hcldz3, Frequency: 1
# Word: 2o12, Frequency: 1
# Word: 1211, Frequency: 1
# Word: pau, Frequency: 1
# Word: monarchist, Frequency: 1
# Word: 2016makes, Frequency: 1
# Word: omdrcv1x1z, Frequency: 1
# Word: usrd52yven, Frequency: 1
# Word: globule, Frequency: 1
# Word: 5btigafgip, Frequency: 1
# Word: zuqlyjx0a1, Frequency: 1
# Word: kimanne123, Frequency: 1
# Word: hu7esdkr7d, Frequency: 1
# Word: flippancy, Frequency: 1
# Word: aplenty, Frequency: 1
# Word: xiwbx3bqwc, Frequency: 1
# Word: axgov3lizx, Frequency: 1
# Word: mf3twe05r6, Frequency: 1
# Word: sunburnt, Frequency: 1
# Word: knocker, Frequency: 1
# Word: afouavw80u, Frequency: 1
# Word: tja9wobfxg, Frequency: 1
# Word: awg53fejfu, Frequency: 1
# Word: 2016including, Frequency: 1
# Word: humorless, Frequency: 1
# Word: 2016fundamental, Frequency: 1
# Word: carpeting, Frequency: 1
# Word: bjzybny5my4featured, Frequency: 1
# Word: voj0rlgncw, Frequency: 1
# Word: xrgvm5tmsc, Frequency: 1
# Word: k59hlnzmhk, Frequency: 1
# Word: smxrjfommi4featured, Frequency: 1
# Word: weatherproof, Frequency: 1
# Word: zoff2qysjk, Frequency: 1
# Word: 2016flashback, Frequency: 1
# Word: emdj3rmzfz, Frequency: 1
# Word: beget, Frequency: 1
# Word: 65hgqtdbio, Frequency: 1
# Word: prattling, Frequency: 1
# Word: internist, Frequency: 1
# Word: wjcjjovbm5, Frequency: 1
# Word: fb5yn5gmpq, Frequency: 1
# Word: soacwahh6n, Frequency: 1
# Word: wkodgwtf9g, Frequency: 1
# Word: v375rbtuew, Frequency: 1
# Word: 38p82c0mim, Frequency: 1
# Word: 300x, Frequency: 1
# Word: trump725, Frequency: 1
# Word: 10022mr, Frequency: 1
# Word: 2ndlt, Frequency: 1
# Word: hm3, Frequency: 1
# Word: 2lt, Frequency: 1
# Word: lupe, Frequency: 1
# Word: sjdh3gde0l, Frequency: 1
# Word: mgnvn3j71i, Frequency: 1
# Word: 2016working, Frequency: 1
# Word: ounzuzmal0, Frequency: 1
# Word: 2016loves, Frequency: 1
# Word: 4obhahyj8j, Frequency: 1
# Word: ojrxvkoz9w, Frequency: 1
# Word: uqvaqoxlm9, Frequency: 1
# Word: l8rrrydvs1, Frequency: 1
# Word: 2016promised, Frequency: 1
# Word: c2pqqyg1c9, Frequency: 1
# Word: immsha8arq, Frequency: 1
# Word: swin24, Frequency: 1
# Word: gci0vbvmpj, Frequency: 1
# Word: o3ngwy7egn, Frequency: 1
# Word: 2016mrs, Frequency: 1
# Word: 2twejg2pvp, Frequency: 1
# Word: icz9euw1aw, Frequency: 1
# Word: v4b2i8aexm, Frequency: 1
# Word: 2016list, Frequency: 1
# Word: grammatically, Frequency: 1
# Word: c7cdhcvld2, Frequency: 1
# Word: _nevertrump, Frequency: 1
# Word: waterfall, Frequency: 1
# Word: 3u34afeatured, Frequency: 1
# Word: inextricable, Frequency: 1
# Word: inapt, Frequency: 1
# Word: 4fw0luiuxc, Frequency: 1
# Word: 2016find, Frequency: 1
# Word: d2e6nou9lw, Frequency: 1
# Word: 2016general, Frequency: 1
# Word: oiler, Frequency: 1
# Word: frightful, Frequency: 1
# Word: 2016erick, Frequency: 1
# Word: 2016jeb, Frequency: 1
# Word: gxj4aho8yk, Frequency: 1
# Word: 2016d, Frequency: 1
# Word: ecate484k7, Frequency: 1
# Word: 0q8bv3cfoq, Frequency: 1
# Word: 2016left, Frequency: 1
# Word: 4v4inebx4d, Frequency: 1
# Word: civic_thoughts, Frequency: 1
# Word: 2016news, Frequency: 1
# Word: 6rrikrvwon, Frequency: 1
# Word: 2016enough, Frequency: 1
# Word: 3700, Frequency: 1
# Word: di77nxhloi, Frequency: 1
# Word: 2016directly, Frequency: 1
# Word: 2013trump, Frequency: 1
# Word: tyronem07172460, Frequency: 1
# Word: bateman, Frequency: 1
# Word: 2016lmaoooo, Frequency: 1
# Word: 2016mothers, Frequency: 1
# Word: 2016mother, Frequency: 1
# Word: 7089, Frequency: 1
# Word: 2016rather, Frequency: 1
# Word: vs2smz9m6z, Frequency: 1
# Word: g3vmzzk8fe, Frequency: 1
# Word: dd977hsyqq, Frequency: 1
# Word: mtu1qi5p6a, Frequency: 1
# Word: qn3agnq2qikfeatured, Frequency: 1
# Word: bhpweo7b7eofeatured, Frequency: 1
# Word: 2016none, Frequency: 1
# Word: 2016shroyer, Frequency: 1
# Word: z8kucdyqny, Frequency: 1
# Word: tpuz9xfvba, Frequency: 1
# Word: 5nepx2y9a9, Frequency: 1
# Word: 2016stupid, Frequency: 1
# Word: jp4rf7e4sf, Frequency: 1
# Word: marcella, Frequency: 1
# Word: bahshczw65, Frequency: 1
# Word: uake0p3sjrhttps, Frequency: 1
# Word: fa9ggz91u6, Frequency: 1
# Word: 2016harth, Frequency: 1
# Word: 614383415410204, Frequency: 1
# Word: bloodcurdling, Frequency: 1
# Word: tce7ntfyne, Frequency: 1
# Word: jb2t0kh8jn, Frequency: 1
# Word: n1s7kevu4v, Frequency: 1
# Word: axqxjbwls9, Frequency: 1
# Word: gbrefqv0fy, Frequency: 1
# Word: jwcu5azhld, Frequency: 1
# Word: ojhgj1hkuq, Frequency: 1
# Word: zf6fw8sw6d, Frequency: 1
# Word: 2016legally, Frequency: 1
# Word: cussed, Frequency: 1
# Word: x5nusi6aun, Frequency: 1
# Word: western_triumph, Frequency: 1
# Word: 9kgpzblrlk, Frequency: 1
# Word: 2016close, Frequency: 1
# Word: 2016wanna, Frequency: 1
# Word: 2016blacks, Frequency: 1
# Word: 2016western, Frequency: 1
# Word: 2hzp2qrwnj, Frequency: 1
# Word: 9zzll0ftr4, Frequency: 1
# Word: aagi7yh2ov, Frequency: 1
# Word: 1ey07bkwbn, Frequency: 1
# Word: csy7ozt4tr, Frequency: 1
# Word: kvvt2tgwfd, Frequency: 1
# Word: o3ohahfr77, Frequency: 1
# Word: 2016yay, Frequency: 1
# Word: 7glfirhlho, Frequency: 1
# Word: 7vbehdenqd, Frequency: 1
# Word: bbpex5vrq5, Frequency: 1
# Word: ik5adtqul2, Frequency: 1
# Word: b1oy1yiilu, Frequency: 1
# Word: kahjrbh84d, Frequency: 1
# Word: undisputable, Frequency: 1
# Word: bcjup2aiv4, Frequency: 1
# Word: 0fogaom9xp, Frequency: 1
# Word: stomaching, Frequency: 1
# Word: gyshbet9as, Frequency: 1
# Word: xahmq2su1q, Frequency: 1
# Word: hyuqlzk8s5, Frequency: 1
# Word: 2016describing, Frequency: 1
# Word: nqlavey8mp, Frequency: 1
# Word: 0075, Frequency: 1
# Word: 4ths, Frequency: 1
# Word: 0quzzreagp, Frequency: 1
# Word: klohofqwk4, Frequency: 1
# Word: qeftnttwy3, Frequency: 1
# Word: lkuwa1km6o, Frequency: 1
# Word: 2016manafort, Frequency: 1
# Word: wml166jhqz, Frequency: 1
# Word: 7yr, Frequency: 1
# Word: 20164wait, Frequency: 1
# Word: kath, Frequency: 1
# Word: oueit88shg, Frequency: 1
# Word: vmcgxyhu3k, Frequency: 1
# Word: ayhkcdgx1z, Frequency: 1
# Word: wq5xzbhxxi, Frequency: 1
# Word: p64wn0iutr, Frequency: 1
# Word: _______, Frequency: 1
# Word: 2016gop, Frequency: 1
# Word: ymtr3trgj8, Frequency: 1
# Word: llama, Frequency: 1
# Word: 2016omg, Frequency: 1
# Word: 9ccpz4lmsm, Frequency: 1
# Word: angels4autism, Frequency: 1
# Word: 4a4obprau8, Frequency: 1
# Word: tentacular, Frequency: 1
# Word: blasphemously, Frequency: 1
# Word: smoky, Frequency: 1
# Word: ceoocf87l5, Frequency: 1
# Word: yp9jharbsf, Frequency: 1
# Word: qxvtcridu3, Frequency: 1
# Word: utmlqcq0jw, Frequency: 1
# Word: mt438wvf2w, Frequency: 1
# Word: 2016inspiration, Frequency: 1
# Word: is5ijqma4m, Frequency: 1
# Word: disunify, Frequency: 1
# Word: 1l, Frequency: 1
# Word: overrunning, Frequency: 1
# Word: cloddish, Frequency: 1
# Word: ggw5ldcct4, Frequency: 1
# Word: uvd9hjpex9, Frequency: 1
# Word: 2016colbert, Frequency: 1
# Word: cspan3, Frequency: 1
# Word: dhyniukb1g, Frequency: 1
# Word: yv9fky7twc, Frequency: 1
# Word: inexact, Frequency: 1
# Word: 8xmwkbv_cowfeatured, Frequency: 1
# Word: 14gnqntcsb, Frequency: 1
# Word: uwewno8ij3, Frequency: 1
# Word: 8a3llfwi8q, Frequency: 1
# Word: 1dil7w69bh, Frequency: 1
# Word: ezcr5nynmm, Frequency: 1
# Word: 3auzrornckfeatured, Frequency: 1
# Word: svayl1zgcd, Frequency: 1
# Word: m4cq62ys2c, Frequency: 1
# Word: mangling, Frequency: 1
# Word: bmbqyi1y4v, Frequency: 1
# Word: rockwood, Frequency: 1
# Word: 6s9gmmnrok, Frequency: 1
# Word: 2016question, Frequency: 1
# Word: 72ixo4adpr, Frequency: 1
# Word: pabq16tmuw, Frequency: 1
# Word: a2k0dvzt4v, Frequency: 1
# Word: wc8ios1d1b, Frequency: 1
# Word: 6flmx5lsro, Frequency: 1
# Word: slotted, Frequency: 1
# Word: lucre, Frequency: 1
# Word: wist, Frequency: 1
# Word: kimberlin, Frequency: 1
# Word: mealer, Frequency: 1
# Word: rabbinic, Frequency: 1
# Word: 500296036836329, Frequency: 1
# Word: 848, Frequency: 1
# Word: unbind, Frequency: 1
# Word: adxf7tnkki, Frequency: 1
# Word: ncbi_pubmed, Frequency: 1
# Word: 5tveysuqci, Frequency: 1
# Word: 8hkc1trmee, Frequency: 1
# Word: xlb1shg7ee, Frequency: 1
# Word: xsr33tmufu, Frequency: 1
# Word: arjun, Frequency: 1
# Word: 2016surprisingly, Frequency: 1
# Word: sheepshead, Frequency: 1
# Word: lvcjo0pkrn, Frequency: 1
# Word: 2472, Frequency: 1
# Word: redheaded, Frequency: 1
# Word: f6mumswgvp, Frequency: 1
# Word: thickening, Frequency: 1
# Word: commandeer, Frequency: 1
# Word: 2016furthermore, Frequency: 1
# Word: 4j5tzvcluk, Frequency: 1
# Word: 2016brown, Frequency: 1
# Word: aa2lz0vlcn, Frequency: 1
# Word: kjxaczljc8, Frequency: 1
# Word: uvziop9drl, Frequency: 1
# Word: lm5szjzmb6, Frequency: 1
# Word: 2016barry, Frequency: 1
# Word: 01000110, Frequency: 1
# Word: 01010101, Frequency: 1
# Word: 2016didnt, Frequency: 1
# Word: tfbusvzn3i, Frequency: 1
# Word: gnu, Frequency: 1
# Word: 2016dowd, Frequency: 1
# Word: ticker, Frequency: 1
# Word: trumpeter, Frequency: 1
# Word: pouch, Frequency: 1
# Word: jmensx7lqigfeatured, Frequency: 1
# Word: permanency, Frequency: 1
# Word: ukulele, Frequency: 1
# Word: roughhousing, Frequency: 1
# Word: jnrun_af0h0featured, Frequency: 1
# Word: hyphenate, Frequency: 1
# Word: 2016isn, Frequency: 1
# Word: tardiness, Frequency: 1
# Word: tlqx0p721y, Frequency: 1
# Word: iux5iaersb, Frequency: 1
# Word: bdd4, Frequency: 1
# Word: n37cy7h9hk, Frequency: 1
# Word: mt6suqjnsr, Frequency: 1
# Word: zoc3x2xlmk, Frequency: 1
# Word: peilooh3hghttps, Frequency: 1
# Word: farer, Frequency: 1
# Word: anthropoid, Frequency: 1
# Word: nosing, Frequency: 1
# Word: tabulate, Frequency: 1
# Word: malformed, Frequency: 1
# Word: zqy0pywhki, Frequency: 1
# Word: 4ljbpsm8xa, Frequency: 1
# Word: xv8q1guwih, Frequency: 1
# Word: 3sl397rxzr, Frequency: 1
# Word: counteroffer, Frequency: 1
# Word: calcify, Frequency: 1
# Word: xjrm500its, Frequency: 1
# Word: 114th, Frequency: 1
# Word: agu463ztn4, Frequency: 1
# Word: 5lx34uw8z2, Frequency: 1
# Word: 2016traffic, Frequency: 1
# Word: mp8japs0je, Frequency: 1
# Word: 2016holly, Frequency: 1
# Word: 2016ali, Frequency: 1
# Word: r7jbtsvysh, Frequency: 1
# Word: 9neolmflis, Frequency: 1
# Word: oje6zirl9e, Frequency: 1
# Word: 2016christy, Frequency: 1
# Word: fl1u9r6vxm, Frequency: 1
# Word: 2016something, Frequency: 1
# Word: 2016declaration, Frequency: 1
# Word: colonist, Frequency: 1
# Word: nyy5wuhz5m, Frequency: 1
# Word: dvl0qoo52m, Frequency: 1
# Word: wqcxfa4pi2, Frequency: 1
# Word: qbdr5mbnle, Frequency: 1
# Word: i2lnlfuqnt, Frequency: 1
# Word: lr5grwuuqz, Frequency: 1
# Word: spitter, Frequency: 1
# Word: croaky, Frequency: 1
# Word: fhkiaa6bx5, Frequency: 1
# Word: 2016meghan, Frequency: 1
# Word: 2016two, Frequency: 1
# Word: 4z9es6mc61, Frequency: 1
# Word: bmfjhoqv3l, Frequency: 1
# Word: pbj63h2pzx, Frequency: 1
# Word: 8szbfign5e, Frequency: 1
# Word: 78hhi5wvf1, Frequency: 1
# Word: zyomso3skd, Frequency: 1
# Word: wh63uzmhdh, Frequency: 1
# Word: jhyzaous3r, Frequency: 1
# Word: 78dmzh38mn, Frequency: 1
# Word: prig, Frequency: 1
# Word: goyim, Frequency: 1
# Word: bonehead1, Frequency: 1
# Word: bonehead, Frequency: 1
# Word: slapdash, Frequency: 1
# Word: hb1411, Frequency: 1
# Word: sqe12d0mbj, Frequency: 1
# Word: gaxjx4owee, Frequency: 1
# Word: 2rk3idl8ry8featured, Frequency: 1
# Word: bossing, Frequency: 1
# Word: fusty, Frequency: 1
# Word: 7tgez5q3td, Frequency: 1
# Word: 2016square, Frequency: 1
# Word: ywxc8d8cj6, Frequency: 1
# Word: xxz5mtfsde, Frequency: 1
# Word: 2016star, Frequency: 1
# Word: dilr6dphz4, Frequency: 1
# Word: gvexx4s4qq, Frequency: 1
# Word: deliciously, Frequency: 1
# Word: 2016welcome, Frequency: 1
# Word: y6phjnlcz6, Frequency: 1
# Word: pf4wvahoo2, Frequency: 1
# Word: jess_mc, Frequency: 1
# Word: syt7ccimwp, Frequency: 1
# Word: brashness, Frequency: 1
# Word: 1839, Frequency: 1
# Word: inventive, Frequency: 1
# Word: inurement, Frequency: 1
# Word: geg2nxwyff, Frequency: 1
# Word: youve, Frequency: 1
# Word: qzok0vv0aq, Frequency: 1
# Word: 2cj6mo8hmx, Frequency: 1
# Word: 2016mcgarry, Frequency: 1
# Word: ggdiiao5pdo, Frequency: 1
# Word: diabetic, Frequency: 1
# Word: mele, Frequency: 1
# Word: 6egurarkw7, Frequency: 1
# Word: turndown, Frequency: 1
# Word: flogging, Frequency: 1
# Word: qgiara8ywd, Frequency: 1
# Word: 2016scottish, Frequency: 1
# Word: yo0twn5bct, Frequency: 1
# Word: embarkation, Frequency: 1
# Word: e9ykigoqnv, Frequency: 1
# Word: tizb0ltvg5, Frequency: 1
# Word: reprobate, Frequency: 1
# Word: prekindergarten, Frequency: 1
# Word: caseymattox_, Frequency: 1
# Word: pswise1, Frequency: 1
# Word: somhrd50, Frequency: 1
# Word: allen1006, Frequency: 1
# Word: midasrex1998, Frequency: 1
# Word: hendog127, Frequency: 1
# Word: professionalization, Frequency: 1
# Word: latchman, Frequency: 1
# Word: reeve, Frequency: 1
# Word: 7o6fqfbn72, Frequency: 1
# Word: kinky, Frequency: 1
# Word: 2krpifimhx, Frequency: 1
# Word: sfc0tmhd6x, Frequency: 1
# Word: 2016score, Frequency: 1
# Word: harmfulness, Frequency: 1
# Word: boarder, Frequency: 1
# Word: c4news, Frequency: 1
# Word: 2016man, Frequency: 1
# Word: cvvmyvc73o, Frequency: 1
# Word: 2016gloucester, Frequency: 1
# Word: m4, Frequency: 1
# Word: 2016currently, Frequency: 1
# Word: crawley, Frequency: 1
# Word: 2016picture, Frequency: 1
# Word: tsb56jauww, Frequency: 1
# Word: 2016about, Frequency: 1
# Word: 87rqfkihov, Frequency: 1
# Word: 2016italian, Frequency: 1
# Word: lifeguard, Frequency: 1
# Word: pastorally, Frequency: 1
# Word: 40x, Frequency: 1
# Word: juvenility, Frequency: 1
# Word: gcb_geqoqiefeatured, Frequency: 1
# Word: pentobarbital, Frequency: 1
# Word: condign, Frequency: 1
# Word: lubricate, Frequency: 1
# Word: undertow, Frequency: 1
# Word: 3hwail2xkoy, Frequency: 1
# Word: 5smaher, Frequency: 1
# Word: blackwood, Frequency: 1
# Word: twat, Frequency: 1
# Word: tobogganist, Frequency: 1
# Word: nonce, Frequency: 1
# Word: 2954, Frequency: 1
# Word: 2632, Frequency: 1
# Word: 278th, Frequency: 1
# Word: 775th, Frequency: 1
# Word: mcdsqyz2jy, Frequency: 1
# Word: 2016within, Frequency: 1
# Word: yet5lozdpt, Frequency: 1
# Word: 0esvro46ei, Frequency: 1
# Word: 2016join, Frequency: 1
# Word: u0u3ashvox, Frequency: 1
# Word: mcl5841lf8, Frequency: 1
# Word: rabkr0gwxy, Frequency: 1
# Word: disembowel, Frequency: 1
# Word: 2016scotland, Frequency: 1
# Word: beneficially, Frequency: 1
# Word: affirmance, Frequency: 1
# Word: civilizational, Frequency: 1
# Word: electrify, Frequency: 1
# Word: dumdum, Frequency: 1
# Word: sb1070, Frequency: 1
# Word: nabs, Frequency: 1
# Word: bloating, Frequency: 1
# Word: tortilla, Frequency: 1
# Word: 87hwpsfstc, Frequency: 1
# Word: xvjycnafo8, Frequency: 1
# Word: 2016lewis, Frequency: 1
# Word: ybqhc2diy4, Frequency: 1
# Word: 8rpqzvzsuf, Frequency: 1
# Word: 3izrnxmpnk, Frequency: 1
# Word: infatuation, Frequency: 1
# Word: wrenchingly, Frequency: 1
# Word: 896229197165626, Frequency: 1
# Word: 918169401638272, Frequency: 1
# Word: 6lsnwf4gtl, Frequency: 1
# Word: ymzapsied2, Frequency: 1
# Word: 3rqu9terrj, Frequency: 1
# Word: 3vde9shl4k, Frequency: 1
# Word: quzyq3mcey, Frequency: 1
# Word: 6pql7vhgsc, Frequency: 1
# Word: lnjj08fjyg, Frequency: 1
# Word: 2016roy, Frequency: 1
# Word: jf6skawygf, Frequency: 1
# Word: unbinding, Frequency: 1
# Word: newswest9, Frequency: 1
# Word: misbehave, Frequency: 1
# Word: intellectualist, Frequency: 1
# Word: telepathic, Frequency: 1
# Word: 2016robert, Frequency: 1
# Word: ns3uv8ovc3ifeatured, Frequency: 1
# Word: toke, Frequency: 1
# Word: 2016sexton, Frequency: 1
# Word: qp07ufnnjm, Frequency: 1
# Word: ll4cf3rgea, Frequency: 1
# Word: 11fyyf5iqm, Frequency: 1
# Word: elide, Frequency: 1
# Word: iigh7qvnac, Frequency: 1
# Word: altqw8brtc, Frequency: 1
# Word: hjh5ry2r3b, Frequency: 1
# Word: notation, Frequency: 1
# Word: 2016regardless, Frequency: 1
# Word: mystically, Frequency: 1
# Word: fl9ajujank, Frequency: 1
# Word: 70acres, Frequency: 1
# Word: dygft9uy4, Frequency: 1
# Word: zdxxl4y6y6, Frequency: 1
# Word: gi_h_a_d35, Frequency: 1
# Word: lgi9frvpa4, Frequency: 1
# Word: lqqv1vlkxh, Frequency: 1
# Word: p2tzdhhtre, Frequency: 1
# Word: youngish, Frequency: 1
# Word: redefinition, Frequency: 1
# Word: fieriness, Frequency: 1
# Word: j0mo0aengz, Frequency: 1
# Word: yblsx4uez1, Frequency: 1
# Word: goldie, Frequency: 1
# Word: wq9kqrp7da, Frequency: 1
# Word: ylv0m9bgve, Frequency: 1
# Word: 2016serving, Frequency: 1
# Word: 2016walk, Frequency: 1
# Word: l8mebfvhso, Frequency: 1
# Word: bhis3bn4es, Frequency: 1
# Word: 2016me, Frequency: 1
# Word: 70fgu9kein, Frequency: 1
# Word: 50m, Frequency: 1
# Word: wmnrj4e4zy, Frequency: 1
# Word: laxness, Frequency: 1
# Word: allegiant, Frequency: 1
# Word: gourd, Frequency: 1
# Word: exculpate, Frequency: 1
# Word: xnathan30x, Frequency: 1
# Word: 2016banning, Frequency: 1
# Word: manservant, Frequency: 1
# Word: f8cxcneozn, Frequency: 1
# Word: 9du2yedzeo, Frequency: 1
# Word: hvjvzc351j, Frequency: 1
# Word: ze8ou1x0rc, Frequency: 1
# Word: gyuzrf54py, Frequency: 1
# Word: 2016lgbt, Frequency: 1
# Word: 2016xenophobia, Frequency: 1
# Word: orland0, Frequency: 1
# Word: aeq1yjw3pd, Frequency: 1
# Word: xeovjhjl5d, Frequency: 1
# Word: yalqnq5w7r, Frequency: 1
# Word: 922k, Frequency: 1
# Word: w9dvwbz959, Frequency: 1
# Word: 2016terrorists, Frequency: 1
# Word: vlff7wx2ta, Frequency: 1
# Word: 2keep, Frequency: 1
# Word: urflz3nkh6, Frequency: 1
# Word: rrjveyygy9, Frequency: 1
# Word: 2016heartbreaking, Frequency: 1
# Word: w1rxf7o0tn, Frequency: 1
# Word: syx4c8uqbs, Frequency: 1
# Word: 2k, Frequency: 1
# Word: vkm28hnjdl, Frequency: 1
# Word: 26k, Frequency: 1
# Word: h7ib7xg0na, Frequency: 1
# Word: 7ofkpwholg, Frequency: 1
# Word: 3obobdomkt, Frequency: 1
# Word: 2016woke, Frequency: 1
# Word: 2016democratic, Frequency: 1
# Word: sjiy3pfayj, Frequency: 1
# Word: thermostat, Frequency: 1
# Word: tribble, Frequency: 1
# Word: qj1yjc1d71, Frequency: 1
# Word: ihuqggow37, Frequency: 1
# Word: sgiekgx998, Frequency: 1
# Word: rane, Frequency: 1
# Word: hoar, Frequency: 1
# Word: 5rssr7qoci, Frequency: 1
# Word: 2016california, Frequency: 1
# Word: noma, Frequency: 1
# Word: 1fgmp5znhp, Frequency: 1
# Word: extortioner, Frequency: 1
# Word: iniquity, Frequency: 1
# Word: d5zrduvo8j, Frequency: 1
# Word: wqpbafjl8n, Frequency: 1
# Word: goy, Frequency: 1
# Word: certifiable, Frequency: 1
# Word: ndcwzzfny9, Frequency: 1
# Word: 2016bam, Frequency: 1
# Word: y6qupowx9k, Frequency: 1
# Word: expressively, Frequency: 1
# Word: 4money, Frequency: 1
# Word: distillery, Frequency: 1
# Word: 0c1jiaqxwn, Frequency: 1
# Word: axlnlywcv2, Frequency: 1
# Word: wmbc1er1mq, Frequency: 1
# Word: scv8ukgun2, Frequency: 1
# Word: oyi604jine, Frequency: 1
# Word: 2016hhhhhh, Frequency: 1
# Word: african_american, Frequency: 1
# Word: 43jhxdyg2i, Frequency: 1
# Word: hlne5gysdk, Frequency: 1
# Word: jvesxxusa1, Frequency: 1
# Word: osxsmkwdt0, Frequency: 1
# Word: tali, Frequency: 1
# Word: declaim, Frequency: 1
# Word: t7jgnsf74d, Frequency: 1
# Word: 2016twittertwitterstreep, Frequency: 1
# Word: eunif2nveo, Frequency: 1
# Word: flimsiness, Frequency: 1
# Word: bloodshot, Frequency: 1
# Word: 2016sasse, Frequency: 1
# Word: tbx6xbwk5q, Frequency: 1
# Word: n84mk7pjjm, Frequency: 1
# Word: cudlrwhq1n, Frequency: 1
# Word: fp7mcvfugq, Frequency: 1
# Word: 3cebq2jsdh, Frequency: 1
# Word: infirmary, Frequency: 1
# Word: vic8jwxnkx, Frequency: 1
# Word: m5dc2l8j6uufeatured, Frequency: 1
# Word: 2015people, Frequency: 1
# Word: tiiibgy80b, Frequency: 1
# Word: curial, Frequency: 1
# Word: 49qufrcrlv, Frequency: 1
# Word: noncriminal, Frequency: 1
# Word: 1247, Frequency: 1
# Word: quarried, Frequency: 1
# Word: nzgh3zkuxc, Frequency: 1
# Word: m9imvpxzy1, Frequency: 1
# Word: inhaler, Frequency: 1
# Word: 2016noticing, Frequency: 1
# Word: oscillate, Frequency: 1
# Word: fatty, Frequency: 1
# Word: dtbv75zcng, Frequency: 1
# Word: 2016confirmed, Frequency: 1
# Word: 7ggeruruvu, Frequency: 1
# Word: 2016rush, Frequency: 1
# Word: mildew, Frequency: 1
# Word: discography, Frequency: 1
# Word: unreligious, Frequency: 1
# Word: unstopped, Frequency: 1
# Word: ymt4mglwyo, Frequency: 1
# Word: oujj1bet81, Frequency: 1
# Word: fox10here, Frequency: 1
# Word: 19h8boqsrf, Frequency: 1
# Word: byknkbnaa0, Frequency: 1
# Word: mshan1fnhh, Frequency: 1
# Word: k24ei0fgq6, Frequency: 1
# Word: scrutinization, Frequency: 1
# Word: ybtmm3adve, Frequency: 1
# Word: quwwpkw7us, Frequency: 1
# Word: mongrelization, Frequency: 1
# Word: 1013, Frequency: 1
# Word: pusher, Frequency: 1
# Word: 2016autocorrect, Frequency: 1
# Word: 4ipldtm9gj, Frequency: 1
# Word: fb4b6ik6uj, Frequency: 1
# Word: bwhct6bvju, Frequency: 1
# Word: 1988cjapb4, Frequency: 1
# Word: unexcited, Frequency: 1
# Word: unexciting, Frequency: 1
# Word: proselytize, Frequency: 1
# Word: 9huadsawux, Frequency: 1
# Word: serenader, Frequency: 1
# Word: 52fpgijhdh, Frequency: 1
# Word: f7ezoaewo8, Frequency: 1
# Word: chowk, Frequency: 1
# Word: fsxjvhu4ht, Frequency: 1
# Word: supergun, Frequency: 1
# Word: 10153565461001680, Frequency: 1
# Word: pygmy, Frequency: 1
# Word: haver, Frequency: 1
# Word: f3z1uwhvy9, Frequency: 1
# Word: 2016leave, Frequency: 1
# Word: 10153777810687144, Frequency: 1
# Word: lmuzi20jco, Frequency: 1
# Word: tanned, Frequency: 1
# Word: dm2h7sayjx, Frequency: 1
# Word: 2016marco, Frequency: 1
# Word: fokkx3t4tc, Frequency: 1
# Word: 8buhj11n48, Frequency: 1
# Word: 10153577369722452, Frequency: 1
# Word: mush, Frequency: 1
# Word: s2ya6muayu, Frequency: 1
# Word: t6jsccygcq, Frequency: 1
# Word: lpbdtqgyo9, Frequency: 1
# Word: zuxvhbv7wf, Frequency: 1
# Word: rw3mi8a2pn, Frequency: 1
# Word: unmonitored, Frequency: 1
# Word: minny, Frequency: 1
# Word: 44am, Frequency: 1
# Word: baccara, Frequency: 1
# Word: precedential, Frequency: 1
# Word: 29am, Frequency: 1
# Word: 2uacv3km7j, Frequency: 1
# Word: bftr1gdrx3, Frequency: 1
# Word: pfund, Frequency: 1
# Word: b1bovnfoex, Frequency: 1
# Word: spewer, Frequency: 1
# Word: deathblow, Frequency: 1
# Word: millhouse, Frequency: 1
# Word: ensemble, Frequency: 1
# Word: olz2uhblqo, Frequency: 1
# Word: wyss, Frequency: 1
# Word: nondenominational, Frequency: 1
# Word: depopulate, Frequency: 1
# Word: pcib5gbemaschool, Frequency: 1
# Word: ueohfj2nph, Frequency: 1
# Word: 2016next, Frequency: 1
# Word: ux1xk0etww, Frequency: 1
# Word: tuidqxb4dv, Frequency: 1
# Word: pkkz2looni, Frequency: 1
# Word: 2016wacko, Frequency: 1
# Word: ylruk9inq1, Frequency: 1
# Word: 1555955044709451, Frequency: 1
# Word: crash3, Frequency: 1
# Word: alx1shhgci2, Frequency: 1
# Word: nerh9bgiop3, Frequency: 1
# Word: nsmmfgcbbw4, Frequency: 1
# Word: w1htwteos05, Frequency: 1
# Word: fqmh682gwz, Frequency: 1
# Word: wlozl3nqry, Frequency: 1
# Word: holden114, Frequency: 1
# Word: mdv3kliw6v, Frequency: 1
# Word: 2016ironically, Frequency: 1
# Word: 7sg4syrapa, Frequency: 1
# Word: mj830qbtmg, Frequency: 1
# Word: p4dax9gz5u, Frequency: 1
# Word: o16xq9hiux, Frequency: 1
# Word: f8uuriczsq, Frequency: 1
# Word: 10153506293466833, Frequency: 1
# Word: bnd8obtmn4, Frequency: 1
# Word: ___________, Frequency: 1
# Word: gvpotvizy8, Frequency: 1
# Word: sb1446, Frequency: 1
# Word: ab1176, Frequency: 1
# Word: invert, Frequency: 1
# Word: merriment, Frequency: 1
# Word: 04vidc5g7t, Frequency: 1
# Word: dz9lahhfry, Frequency: 1
# Word: mikesmith8026, Frequency: 1
# Word: gregabbott_tx, Frequency: 1
# Word: 2015if, Frequency: 1
# Word: blisteringly, Frequency: 1
# Word: 3nnu3xeuid, Frequency: 1
# Word: xtkzfw02aq, Frequency: 1
# Word: 2016amen, Frequency: 1
# Word: svelte, Frequency: 1
# Word: glokof3nzk, Frequency: 1
# Word: 2016res, Frequency: 1
# Word: ymjlljo3mg, Frequency: 1
# Word: a326ap0mn1, Frequency: 1
# Word: 2015willett, Frequency: 1
# Word: pedophilic, Frequency: 1
# Word: ysweto5nfs, Frequency: 1
# Word: 2016afterwards, Frequency: 1
# Word: regale, Frequency: 1
# Word: underselling, Frequency: 1
# Word: 2015however, Frequency: 1
# Word: foulmouthed, Frequency: 1
# Word: upholstery, Frequency: 1
# Word: sanded, Frequency: 1
# Word: 5the, Frequency: 1
# Word: _julmplporw, Frequency: 1
# Word: 1473214698, Frequency: 1
# Word: 10206543775341127, Frequency: 1
# Word: sc9ioe1l4t, Frequency: 1
# Word: ungodliness, Frequency: 1
# Word: pessimistically, Frequency: 1
# Word: agora, Frequency: 1
# Word: chive, Frequency: 1
# Word: sundowner, Frequency: 1
# Word: inborn, Frequency: 1
# Word: ejwznda0ntczmty0tzaynzaymnmzriiymgkimjmiirizyercugmoegeahxkvfg, Frequency: 1
# Word: 10157643178105206, Frequency: 1
# Word: 1073741894, Frequency: 1
# Word: 10157643178270206, Frequency: 1
# Word: 10157647965685206, Frequency: 1
# Word: 1073741897, Frequency: 1
# Word: 10157647965990206, Frequency: 1
# Word: breakfree2016, Frequency: 1
# Word: lbynha5bkt, Frequency: 1
# Word: gluten, Frequency: 1
# Word: wispy, Frequency: 1
# Word: ktla5, Frequency: 1
# Word: barbershop, Frequency: 1
# Word: glxpzc2uiz, Frequency: 1
# Word: l2pk5a, Frequency: 1
# Word: p7, Frequency: 1
# Word: 0featured, Frequency: 1
# Word: fmbl01q1vy, Frequency: 1
# Word: wmwgfpt70e, Frequency: 1
# Word: 10107105609892679, Frequency: 1
# Word: readjustment, Frequency: 1
# Word: thrilling, Frequency: 1
# Word: lrveoz31mf, Frequency: 1
# Word: pruning, Frequency: 1
# Word: 10150112918376371, Frequency: 1
# Word: 279881, Frequency: 1
# Word: 100500271370, Frequency: 1
# Word: 10153375689991371, Frequency: 1
# Word: penitent, Frequency: 1
# Word: testiness, Frequency: 1
# Word: mz7news, Frequency: 1
# Word: 1313426775337589, Frequency: 1
# Word: denver7, Frequency: 1
# ...
# Word: 51s, Frequency: 1
# Word: transistor, Frequency: 1
# Word: 1122sen, Frequency: 1
# Word: assembler, Frequency: 1
# Word: n_, Frequency: 1
# Word: 089, Frequency: 1
# Word: tidiness, Frequency: 1
# Word: rqdvad25chuobama, Frequency: 1
# Word: inveigh, Frequency: 1
# Word: academe, Frequency: 1
# Word: etymology, Frequency: 1
# Word: 952, Frequency: 1
# Word: 1777, Frequency: 1
# Word: 1831, Frequency: 1
# Word: stree, Frequency: 1
# Word: overstock, Frequency: 1
# Word: prophylaxis, Frequency: 1
# Word: bacillus, Frequency: 1
# Word: navigable, Frequency: 1
# Word: texture, Frequency: 1
# Word: cheesecake, Frequency: 1
# Word: jabbering, Frequency: 1
# Word: theodicy, Frequency: 1
# Word: propitiate, Frequency: 1
# Word: 2012cfpb, Frequency: 1
# Word: 194k, Frequency: 1
# Word: 175k, Frequency: 1
# Word: nonhuman, Frequency: 1
# Word: proscription, Frequency: 1
# Word: clasping, Frequency: 1
# Word: posttraumatic, Frequency: 1
# Word: 8x4p0srba9, Frequency: 1
# Word: e82gffdtvv, Frequency: 1
# Word: 0l44f0efb5, Frequency: 1
# Word: fox23, Frequency: 1
# Word: blackfriday2017, Frequency: 1
# Word: dih54vugmu, Frequency: 1
# Word: 2017walmart, Frequency: 1
# Word: mindlessness, Frequency: 1
# Word: mwv1queqac, Frequency: 1
# Word: 20billion, Frequency: 1
# Word: pq56wkrhsq, Frequency: 1
# Word: confectionery, Frequency: 1
# Word: xikvyixq4y, Frequency: 1
# Word: f0nb9x82rm, Frequency: 1
# Word: mkblsjis0r, Frequency: 1
# Word: hkhjidg40s, Frequency: 1
# Word: 9tnze2hbmj, Frequency: 1
# Word: news_executive, Frequency: 1
# Word: 2017snap, Frequency: 1
# Word: yzsqs66dw2, Frequency: 1
# Word: unassigned, Frequency: 1
# Word: cosmic, Frequency: 1
# Word: q10, Frequency: 1
# Word: 274637, Frequency: 1
# Word: tip577, Frequency: 1
# Word: whinny, Frequency: 1
# Word: edjmzdg1yg, Frequency: 1
# Word: 2017independent, Frequency: 1
# Word: 2017campos, Frequency: 1
# Word: 3dr, Frequency: 1
# Word: mediumship, Frequency: 1
# Word: palmistry, Frequency: 1
# Word: seance, Frequency: 1
# Word: herbalism, Frequency: 1
# Word: 6551, Frequency: 1
# Word: mmeyer50, Frequency: 1
# Word: iyrpwf7j1z, Frequency: 1
# Word: 2017simone, Frequency: 1
# Word: 2017kaya, Frequency: 1
# Word: ztk4lvzozl, Frequency: 1
# Word: 2017overall, Frequency: 1
# Word: bandeau, Frequency: 1
# Word: gallivant, Frequency: 1
# Word: vmrrsup43w, Frequency: 1
# Word: 2017sorvino, Frequency: 1
# Word: r84y78kedg, Frequency: 1
# Word: hgihola8vu, Frequency: 1
# Word: rscmrkma63, Frequency: 1
# Word: zr2jxy6jbt, Frequency: 1
# Word: reflag, Frequency: 1
# Word: coffle, Frequency: 1
# Word: nwjeuej7li, Frequency: 1
# Word: tnzxve0rvp, Frequency: 1
# Word: 9iiub2icxk, Frequency: 1
# Word: rg4wnuuyjw, Frequency: 1
# Word: 2017young, Frequency: 1
# Word: gncraux2np, Frequency: 1
# Word: 7uksbhp7xq, Frequency: 1
# Word: 2017atm, Frequency: 1
# Word: pn1prg7rh5, Frequency: 1
# Word: i2hkfqkbfr, Frequency: 1
# Word: 4nd1hr8n1q, Frequency: 1
# Word: c9qezhsgnk, Frequency: 1
# Word: nai2zjyzzt, Frequency: 1
# Word: lqv1rjef7q, Frequency: 1
# Word: s9bv1yiayd, Frequency: 1
# Word: inequal, Frequency: 1
# Word: akmjsat80v, Frequency: 1
# Word: flanking, Frequency: 1
# Word: exhibitionist, Frequency: 1
# Word: mw2vjxzfrn, Frequency: 1
# Word: 40million, Frequency: 1
# Word: snakeskin, Frequency: 1
# Word: parol, Frequency: 1
# Word: wtov9, Frequency: 1
# Word: hfs5azzhvw, Frequency: 1
# Word: 2017steubenville, Frequency: 1
# Word: jr9zje4sgc, Frequency: 1
# Word: cavalryman, Frequency: 1
# Word: iconoclastic, Frequency: 1
# Word: ru8hqvyacb, Frequency: 1
# Word: mozel_tov, Frequency: 1
# Word: hgkevh6x8d, Frequency: 1
# Word: c00uwnygli, Frequency: 1
# Word: ukrdlnn2mv, Frequency: 1
# Word: jdg1oq9hxk, Frequency: 1
# Word: ijq4q2kzrk, Frequency: 1
# Word: qia9jiuczs, Frequency: 1
# Word: 2017kessler, Frequency: 1
# Word: hzypgkucg6, Frequency: 1
# Word: axwls5edpi, Frequency: 1
# Word: yfm9kagu1g, Frequency: 1
# Word: re8dwumrfd, Frequency: 1
# Word: rebelutionary_z, Frequency: 1
# Word: rut4v1kmdw, Frequency: 1
# Word: 2017la, Frequency: 1
# Word: fdxfy6xwu5, Frequency: 1
# Word: y4jek7ecu4, Frequency: 1
# Word: mrb7xu4txt, Frequency: 1
# Word: jfe6vxtawg, Frequency: 1
# Word: mxlmdqwg4p, Frequency: 1
# Word: 2wskojhfe5, Frequency: 1
# Word: 2017uzinyc, Frequency: 1
# Word: x7141, Frequency: 1
# Word: 15252, Frequency: 1
# Word: 7141, Frequency: 1
# Word: 1800222tips, Frequency: 1
# Word: advocator, Frequency: 1
# Word: overeducated, Frequency: 1
# Word: gxgnzgpi1h, Frequency: 1
# Word: 884063000793165824the, Frequency: 1
# Word: fox43, Frequency: 1
# Word: muvsqtxqf8, Frequency: 1
# Word: dalliance, Frequency: 1
# Word: 3003, Frequency: 1
# Word: bbc1, Frequency: 1
# Word: xvhdc4kcgz, Frequency: 1
# Word: 2017cleanliness, Frequency: 1
# Word: lauren_southern, Frequency: 1
# Word: drahkbx45h, Frequency: 1
# Word: 2017listen, Frequency: 1
# Word: udcj0autbk, Frequency: 1
# Word: mxymkl8eln, Frequency: 1
# Word: 32s8f3m4vb, Frequency: 1
# Word: h3gc534pup, Frequency: 1
# Word: 2017family, Frequency: 1
# Word: 7newssydney, Frequency: 1
# Word: pacer, Frequency: 1
# Word: moonless, Frequency: 1
# Word: architecturally, Frequency: 1
# Word: khanum, Frequency: 1
# Word: 1984a, Frequency: 1
# Word: zkytu7m95pq, Frequency: 1
# Word: b5hmirwcwn, Frequency: 1
# Word: hiuvknfk7z, Frequency: 1
# Word: 2017target, Frequency: 1
# Word: 2017riot, Frequency: 1
# Word: zzucqevt3m, Frequency: 1
# Word: 2017group, Frequency: 1
# Word: smlgveorq5, Frequency: 1
# Word: 2016arrestees, Frequency: 1
# Word: 9imhqrei1a, Frequency: 1
# Word: fyenmipk3y, Frequency: 1
# Word: _6mzc5kpr3sif, Frequency: 1
# Word: tyler_bridges, Frequency: 1
# Word: 851214160042106880, Frequency: 1
# Word: 851223662976004096, Frequency: 1
# Word: 132930349, Frequency: 1
# Word: smudge, Frequency: 1
# Word: 9chcrruiiv, Frequency: 1
# Word: 2017grandmother, Frequency: 1
# Word: oy9h7watit, Frequency: 1
# Word: p5uvjm4ek8, Frequency: 1
# Word: a2ms2xqmhn, Frequency: 1
# Word: 90kg, Frequency: 1
# Word: 268kg, Frequency: 1
# Word: 19kg, Frequency: 1
# Word: 223kg, Frequency: 1
# Word: qs9o7xulwsw, Frequency: 1
# Word: 829894370123927556, Frequency: 1
# Word: xilsmku67q0, Frequency: 1
# Word: gr0g7rkohd, Frequency: 1
# Word: yu7m2h6ov8, Frequency: 1
# Word: ipqrimr8gww, Frequency: 1
# Word: fjn3wq7p7p, Frequency: 1
# Word: xtvcoy9pwc, Frequency: 1
# Word: 9bajc0h2bu, Frequency: 1
# Word: 2017folks, Frequency: 1
# Word: 3400, Frequency: 1
# Word: ty2rbok0je, Frequency: 1
# Word: m0z6yrrtui, Frequency: 1
# Word: 2015wichita, Frequency: 1
# Word: 37vv8gybnt, Frequency: 1
# Word: ukokg63ft5, Frequency: 1
# Word: 5463, Frequency: 1
# Word: afw1vjwvwh, Frequency: 1
# Word: 809800916484456448these, Frequency: 1
# Word: h33ohchq64, Frequency: 1
# Word: 911chief, Frequency: 1
# Word: t7tc3gr0d5m, Frequency: 1
# Word: fightfor15, Frequency: 1
# Word: 9aiv8x3yiq, Frequency: 1
# Word: xk1alcekpt, Frequency: 1
# Word: concealer, Frequency: 1
# Word: 80k, Frequency: 1
# Word: 1um9ry2ma8, Frequency: 1
# Word: irrelevant2, Frequency: 1
# Word: be3, Frequency: 1
# Word: money4, Frequency: 1
# Word: exist6, Frequency: 1
# Word: it7, Frequency: 1
# Word: debilitate, Frequency: 1
# Word: hiker, Frequency: 1
# Word: jgx6xrz0zlq, Frequency: 1
# Word: beeiimrcp4evia, Frequency: 1
# Word: n7po5mwtao, Frequency: 1
# Word: germanic, Frequency: 1
# Word: 4vrllnbvp0, Frequency: 1
# Word: r5a1lcmevf, Frequency: 1
# Word: uq8xoonfyn, Frequency: 1
# Word: crimes43, Frequency: 1
# Word: xnxovnjlj9, Frequency: 1
# Word: wakeupwith9, Frequency: 1
# Word: nnl7xg7dkt, Frequency: 1
# Word: og3t2zw2wd, Frequency: 1
# Word: o362ugxmd2, Frequency: 1
# Word: zvsa44, Frequency: 1
# Word: c9xg, Frequency: 1
# Word: luaar0ik7d, Frequency: 1
# Word: 2016lowe, Frequency: 1
# Word: 1n0dcdrsic, Frequency: 1
# Word: eqekquuf0g, Frequency: 1
# Word: betrothed, Frequency: 1
# Word: garble, Frequency: 1
# Word: dqla6, Frequency: 1
# Word: dissolvent, Frequency: 1
# Word: baseboard, Frequency: 1
# Word: nate3914, Frequency: 1
# Word: 9ep3n0zbgv, Frequency: 1
# Word: i5hqsybobl, Frequency: 1
# Word: unapproachable, Frequency: 1
# Word: musculature, Frequency: 1
# Word: chromosome, Frequency: 1
# Word: 765033077995343872https, Frequency: 1
# Word: 764682372746973184https, Frequency: 1
# Word: 764681054846328832jayrome, Frequency: 1
# Word: 764706238894604288here, Frequency: 1
# Word: 764889161623011329here, Frequency: 1
# Word: 764710518443704320here, Frequency: 1
# Word: prxr2prcuv, Frequency: 1
# Word: 61jrpk2q7w, Frequency: 1
# Word: fox6nowresidents, Frequency: 1
# Word: isdvm7qdpz, Frequency: 1
# Word: fox6nowhere, Frequency: 1
# Word: bfdhd3ucyauat, Frequency: 1
# Word: unescorted, Frequency: 1
# Word: jacketed, Frequency: 1
# Word: kctv5police, Frequency: 1
# Word: x47myf3nmz, Frequency: 1
# Word: adbgwqmc77, Frequency: 1
# Word: 2016mark, Frequency: 1
# Word: jmmcm5zull, Frequency: 1
# Word: gbflupy6sx, Frequency: 1
# Word: twitterer, Frequency: 1
# Word: ukwszjezo3, Frequency: 1
# Word: 6gnauwvvfr, Frequency: 1
# Word: u8obkcqhja, Frequency: 1
# Word: fox4terry, Frequency: 1
# Word: duplex, Frequency: 1
# Word: holey, Frequency: 1
# Word: erotica, Frequency: 1
# Word: o2nbednimk, Frequency: 1
# Word: xealntt2g2, Frequency: 1
# Word: malevolence, Frequency: 1
# Word: commissively, Frequency: 1
# Word: ubo5dg9twp4ryan, Frequency: 1
# Word: 2016disney, Frequency: 1
# Word: 11million, Frequency: 1
# Word: rhe, Frequency: 1
# Word: vjxoi26x4s, Frequency: 1
# Word: 133760d, Frequency: 1
# Word: 739160618448609284h, Frequency: 1
# Word: thane, Frequency: 1
# Word: untypical, Frequency: 1
# Word: shader, Frequency: 1
# Word: trilingual, Frequency: 1
# Word: psychosexual, Frequency: 1
# Word: fight4facultyofcolor, Frequency: 1
# Word: l1gtxnczqq, Frequency: 1
# Word: ployment, Frequency: 1
# Word: 1total, Frequency: 1
# Word: graven, Frequency: 1
# Word: rstz9ijd3z, Frequency: 1
# Word: 2016fakih, Frequency: 1
# Word: tomcat, Frequency: 1
# Word: bcby8rxk6z, Frequency: 1
# Word: 2016fawstin, Frequency: 1
# Word: qkvixbp7vs, Frequency: 1
# Word: ep5mfxyf9f, Frequency: 1
# Word: cgl0c4b3gr8via, Frequency: 1
# Word: supplicating, Frequency: 1
# Word: aly, Frequency: 1
# Word: newstalk1010, Frequency: 1
# Word: 749th, Frequency: 1
# Word: recital, Frequency: 1
# Word: ester, Frequency: 1
# Word: spiller, Frequency: 1
# Word: buna, Frequency: 1
# Word: 54b, Frequency: 1
# Word: rlfbmvpx9vssadiq, Frequency: 1
# Word: 7dqat4dvmh, Frequency: 1
# Word: zzpx_bzka40police, Frequency: 1
# Word: therapeutically, Frequency: 1
# Word: bloodstained, Frequency: 1
# Word: ps75, Frequency: 1
# Word: impressionably, Frequency: 1
# Word: unware, Frequency: 1
# Word: 10tv, Frequency: 1
# Word: jackman, Frequency: 1
# Word: referenda, Frequency: 1
# Word: lhj6h9vledaaccording, Frequency: 1
# Word: superfluously, Frequency: 1
# Word: ceremoniously, Frequency: 1
# Word: travertine, Frequency: 1
# Word: granada, Frequency: 1
# Word: 699374499414691840https, Frequency: 1
# Word: 699374593996300288https, Frequency: 1
# Word: 699374547347243008, Frequency: 1
# Word: censorious, Frequency: 1
# Word: miser, Frequency: 1
# Word: leotard, Frequency: 1
# Word: dyqb81bpd9mlive, Frequency: 1
# Word: regionalist, Frequency: 1
# Word: barbate, Frequency: 1
# Word: ironman, Frequency: 1
# Word: 688841370853740544then, Frequency: 1
# Word: 688898296006352896to, Frequency: 1
# Word: 688916800579354624cheadle, Frequency: 1
# Word: 689889591940100099and, Frequency: 1
# Word: gazzetta, Frequency: 1
# Word: 2016kennedy, Frequency: 1
# Word: shrove, Frequency: 1
# Word: kaput, Frequency: 1
# Word: silf8ut4mte, Frequency: 1
# Word: 15whites, Frequency: 1
# Word: 2016islamic, Frequency: 1
# Word: 8000, Frequency: 1
# Word: artesian, Frequency: 1
# Word: 7500, Frequency: 1
# Word: 9800, Frequency: 1
# Word: 9200, Frequency: 1
# Word: 7200, Frequency: 1
# Word: messiness, Frequency: 1
# Word: nonphilosophical, Frequency: 1
# Word: titillation, Frequency: 1
# Word: tarry, Frequency: 1
# Word: 2015major, Frequency: 1
# Word: screwable, Frequency: 1
# Word: menmwxq_0u0the, Frequency: 1
# Word: 2015nicholas, Frequency: 1
# Word: 2015dallas, Frequency: 1
# Word: tipster, Frequency: 1
# Word: olivia_a_ortiz, Frequency: 1
# Word: rhoqqdks1f, Frequency: 1
# Word: 671451417798819840that, Frequency: 1
# Word: gltg2l81bk, Frequency: 1
# Word: 2015black, Frequency: 1
# Word: mtkb57oxhx, Frequency: 1
# Word: 2015because, Frequency: 1
# Word: 671481401984724992, Frequency: 1
# Word: radiator, Frequency: 1
# Word: colorist, Frequency: 1
# Word: ripa, Frequency: 1
# Word: 670836492026163200completely, Frequency: 1
# Word: employable, Frequency: 1
# Word: loo, Frequency: 1
# Word: 16via, Frequency: 1
# Word: 668974136207802368after, Frequency: 1
# Word: 302484198487359490eventually, Frequency: 1
# Word: hetero, Frequency: 1
# Word: ug1wcv0bio, Frequency: 1
# Word: 2015at, Frequency: 1
# Word: l5oi5cslki, Frequency: 1
# Word: monica_alveezy, Frequency: 1
# Word: 667057830000627712wouldn, Frequency: 1
# Word: 1pzgkodpk0, Frequency: 1
# Word: mosser, Frequency: 1
# Word: 01wcckwopi, Frequency: 1
# Word: 2015yeah, Frequency: 1
# Word: rebelliousness, Frequency: 1
# Word: vnd7oxprxn8the, Frequency: 1
# Word: 2015actress, Frequency: 1
# Word: burnout, Frequency: 1
# Word: melter, Frequency: 1
# Word: 1472, Frequency: 1
# Word: dramatist, Frequency: 1
# Word: muss901ra4, Frequency: 1
# Word: 665723350698713088https, Frequency: 1
# Word: 665723459465379840you, Frequency: 1
# Word: majf4ndedp, Frequency: 1
# Word: bs6qn0kdtb, Frequency: 1
# Word: zmji36q8e4ovia, Frequency: 1
# Word: luncheonette, Frequency: 1
# Word: palisade, Frequency: 1
# Word: suboptimal, Frequency: 1
# Word: methodologically, Frequency: 1
# Word: 8uzsqqfv2k, Frequency: 1
# Word: 2015wouldn, Frequency: 1
# Word: qmac1pfpwp, Frequency: 1
# Word: 2015ms, Frequency: 1
# Word: retinitis, Frequency: 1
# Word: malady, Frequency: 1
# Word: decimation, Frequency: 1
# Word: humorously, Frequency: 1
# Word: extrovert, Frequency: 1
# Word: 4210, Frequency: 1
# Word: headpiece, Frequency: 1
# Word: j28efozcgq, Frequency: 1
# Word: racialist, Frequency: 1
# Word: j_xmalvsutkthe, Frequency: 1
# Word: souther, Frequency: 1
# Word: 654310751759298560, Frequency: 1
# Word: dockyard, Frequency: 1
# Word: consecrated, Frequency: 1
# Word: ecclesiological, Frequency: 1
# Word: pray_4_life, Frequency: 1
# Word: 2015planned, Frequency: 1
# Word: fox13now, Frequency: 1
# Word: hysterectomy, Frequency: 1
# Word: boyishly, Frequency: 1
# Word: freakish, Frequency: 1
# Word: fyf911the, Frequency: 1
# Word: takin, Frequency: 1
# Word: m2n2iiruvlomiss, Frequency: 1
# Word: 70007, Frequency: 1
# Word: arborist, Frequency: 1
# Word: alchemical, Frequency: 1
# Word: debord, Frequency: 1
# Word: trin, Frequency: 1
# Word: ngai, Frequency: 1
# Word: ethnography, Frequency: 1
# Word: organicity, Frequency: 1
# Word: avital, Frequency: 1
# Word: uncomprehending, Frequency: 1
# Word: adornment, Frequency: 1
# Word: stratification, Frequency: 1
# Word: queerness, Frequency: 1
# Word: tributary, Frequency: 1
# Word: 2900via, Frequency: 1
# Word: motoring, Frequency: 1
# Word: razorback, Frequency: 1
# Word: 630873997735911424, Frequency: 1
# Word: wort, Frequency: 1
# Word: nudism, Frequency: 1
# Word: grime, Frequency: 1
# Word: thimble, Frequency: 1
# Word: gruesomeness, Frequency: 1
# Word: genome, Frequency: 1
# Word: pundita, Frequency: 1
# Word: ovytgh_kbd0one, Frequency: 1
# Word: selectivity, Frequency: 1
# Word: dicing, Frequency: 1
# Word: pckjiu6iyeu, Frequency: 1
# Word: preborn, Frequency: 1
# Word: vertex, Frequency: 1
# Word: tonal, Frequency: 1
# Word: 2015sheppard, Frequency: 1
# Word: elysia, Frequency: 1
# Word: tambor, Frequency: 1
# Word: 13815, Frequency: 1
# Word: 847, Frequency: 1
# Word: 6181, Frequency: 1
# Word: kashi, Frequency: 1
# Word: 7588, Frequency: 1
# Word: 4vv7gdwojk8sunday, Frequency: 1
# Word: rdidr8mjtbc, Frequency: 1
# Word: 597419872641888256a, Frequency: 1
# Word: 597421745356742657milliere, Frequency: 1
# Word: 597421141125242880and, Frequency: 1
# Word: premiss, Frequency: 1
# Word: atef, Frequency: 1
# Word: mingy, Frequency: 1
# Word: coddler, Frequency: 1
# Word: dakota_meyer, Frequency: 1
# Word: n8fb9sjwan, Frequency: 1
# Word: oes, Frequency: 1
# Word: inhttmxnz2, Frequency: 1
# Word: 2911, Frequency: 1
# Word: 117conversely, Frequency: 1
# Word: meretricious, Frequency: 1
# Word: 36b, Frequency: 1
# Word: electrolysis, Frequency: 1
# Word: thdrhavfiw8the, Frequency: 1
# Word: 5538, Frequency: 1
# Word: 773847, Frequency: 1
# Word: 3353, Frequency: 1
# Word: 3354, Frequency: 1
# Word: 027260, Frequency: 1
# Word: 9299, Frequency: 1
# Word: 3500, Frequency: 1
# Word: dramatization, Frequency: 1
# Word: antihemorrhagic, Frequency: 1
# Word: curette, Frequency: 1
# Word: misrule, Frequency: 1
# Word: distractive, Frequency: 1
# Word: behoove, Frequency: 1
# Word: 1114, Frequency: 1
# Word: 2014if, Frequency: 1
# Word: ec6tmdetik, Frequency: 1

# %%
def remove_non_word_characters(tokens):
    cleaned_tokens = [re.sub(r'[^\w\s]', '', token) for token in tokens]
    return cleaned_tokens

# %%
df['title'] = df['title'].apply(remove_non_word_characters)
df['text'] = df['text'].apply(remove_non_word_characters)

# %%
def remove_hyphenated_words(tokens):
    cleaned_tokens = [token for token in tokens if not token.endswith('-')]
    return cleaned_tokens

# %%
df['title'] = df['title'].apply(remove_hyphenated_words)
df['text'] = df['text'].apply(remove_hyphenated_words)

# %%
def remove_consecutive_duplicates(tokens):
    cleaned_tokens = [tokens[i] for i in range(len(tokens)) if i == 0 or tokens[i] != tokens[i-1]]
    return cleaned_tokens

# %%
df['title'] = df['title'].apply(remove_consecutive_duplicates)
df['text'] = df['text'].apply(remove_consecutive_duplicates)

# %%
# Convert tokenized text back to string
df['title'] = df['title'].apply(lambda x: ' '.join(x))
df['text'] = df['text'].apply(lambda x: ' '.join(x))

# %%
#removing 'u'
df['text'] = df['text'].str.replace(r'\b(u)\b', '', regex=True)

# %%
MostFreq = Counter(" ".join(df['text']).split()).most_common(10)
result = pd.DataFrame(MostFreq, columns=['Word', 'Frequency'])
print(result)
# Out:
#          Word  Frequency
# 0       trump     131489
# 1        said     130291
# 2   president      55030
# 3       would      54510
# 4      people      41237
# 5         one      37208
# 6       state      33715
# 7        also      30992
# 8         new      30830
# 9  government      27484

# %%
words=[]
freq=[]

for word, count in MostFreq:
    words.append(word)
    freq.append(count)

# %%
sns.barplot(x=words, y=freq)
plt.title('Top 10 Most Frequently Occuring Words(Dialogue)')
plt.show()

# %%
cv = CountVectorizer(ngram_range=(2,2))
bigrams = cv.fit_transform(df['text'] )

# %%
from scipy.sparse import csr_matrix

# Convert bigrams to CSR format if it's not already in CSR format
if not isinstance(bigrams, csr_matrix):
    bigrams = bigrams.tocsr()

# Calculate the sum of each column (word frequency)
count_values = bigrams.sum(axis=0)

# Convert count_values to a dense numpy array
count_values = count_values.A.ravel()

# Create a DataFrame with frequency and word columns
ngram_freq = pd.DataFrame({"frequency": count_values, "words": cv.get_feature_names_out()})
ngram_freq = ngram_freq.sort_values(by="frequency", ascending=False)

# %%
sns.barplot(x=ngram_freq['frequency'][:10],y=ngram_freq['words'][:10] )
plt.title('Top 10 Most Frequently Occuring Bigrams')
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Define CountVectorizer with limited max_features
cv1 = CountVectorizer(ngram_range=(3,3), max_features=1000)  # Adjust max_features as needed

# Fit and transform the text column
trigrams = cv1.fit_transform(df['text'])

# Sum the counts of each n-gram
count_values = trigrams.toarray().sum(axis=0)

# Create DataFrame to store n-gram frequencies
ngram_freq = pd.DataFrame(sorted([(count_values[i], k) for k, i in cv1.vocabulary_.items()], reverse=True))
ngram_freq.columns = ["frequency", "words"]

# %%
sns.barplot(x=ngram_freq['frequency'][:10], y=ngram_freq['words'][:10])
plt.title('Top 10 Most Frequently Occuring Trigrams')
plt.show()

# %%
text=" ".join(word for word in df['text'])
word_cloud = WordCloud(
        width=3000,
        height=2000,
        random_state=1,
        background_color="grey",
        colormap="Set2",
        collocations=False,
        stopwords=STOPWORDS,
        ).generate(text)

# %%
plt.imshow(word_cloud)
plt.axis("off")
plt.show()

# %% [markdown]
# using logistic regression for binary classification

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
import sklearn
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
x_features=df.text.values
y_features=df.label.values

# %%
x_features = TfidfVectorizer().fit_transform(x_features)
print(x_features)
# Out:
#   (0, 39754)	0.032047330341778875
#   (0, 4904)	0.05553352976758812
#   (0, 16863)	0.030240016453120303
#   (0, 9758)	0.073733564525967
#   (0, 6397)	0.06549015944146562
#   (0, 7775)	0.13346982692304019
#   (0, 15809)	0.04733101431131955
#   (0, 31025)	0.054132017624482255
#   (0, 18803)	0.03759756857070078
#   (0, 38945)	0.024294516712926373
#   (0, 32330)	0.04919499914898885
#   (0, 34234)	0.045022521682148285
#   (0, 38800)	0.0439439275374246
#   (0, 14580)	0.041126740609627205
#   (0, 24406)	0.07682632943940187
#   (0, 11807)	0.049878281223892464
#   (0, 23376)	0.06531668769291768
#   (0, 16922)	0.04254082853201351
#   (0, 35821)	0.02087137668622419
#   (0, 19665)	0.029362206686793128
#   (0, 7748)	0.06108315426818377
#   (0, 16428)	0.04379704654933655
#   (0, 22971)	0.027108467125410735
#   (0, 38580)	0.07645129876462921
#   (0, 10198)	0.03757268150774614
#   :	:
#   (44688, 35872)	0.04898969099642056
#   (44688, 38836)	0.02620975097821112
#   (44688, 12151)	0.02375621998385283
#   (44688, 30800)	0.03409662811004023
#   (44688, 26611)	0.02867743162550989
#   (44688, 39281)	0.026828693431912493
#   (44688, 35033)	0.029635453406989427
#   (44688, 27692)	0.014766128735224782
#   (44688, 348)	0.026202766793649846
#   (44688, 18568)	0.02637031244846449
#   (44688, 25685)	0.023475898331764715
#   (44688, 31811)	0.04223831532608136
#   (44688, 31616)	0.010506973795379914
#   (44688, 20089)	0.01813379126363037
#   (44688, 33131)	0.030880612107898473
#   (44688, 31809)	0.019571594957437446
#   (44688, 29208)	0.02212512076492556
#   (44688, 7966)	0.015031751243229818
#   (44688, 24684)	0.1002877871104002
#   (44688, 28772)	0.05266095011530879
#   (44688, 15699)	0.03996168279782365
#   (44688, 16337)	0.01884505022667814
#   (44688, 28347)	0.04895308536761032
#   (44688, 23326)	0.02582774114698552
#   (44688, 36321)	0.025987530345490853

# %%
X_train, X_test, y_train, y_test = train_test_split(x_features, y_features, test_size = 0.2, stratify = y_features, random_state = 2)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_accuracy = accuracy_score(X_train_prediction, y_train)
print(training_accuracy)
# Out:
# 0.9801124444071494

# %%
X_test_prediction = model.predict(X_test)
testing_accuracy = accuracy_score(X_test_prediction, y_test)
print(testing_accuracy)
# Out:
# 0.9674423808458268

# %% [markdown]
# using RNN for prediction

# %%
df['text'][0]
# Out:
# 'head conservative republican faction  congress month huge expansion national debt pay tax fiscal conservative budget restraint 2018 keeping sharp pivot way among  representative mark speaking face nation drew hard line federal spending bracing battle return begin trying pass federal budget fight likely linked immigration policy even congressional election approach seek keep control congress president trump want big budget increase military spending also want proportional non defense discretionary spending support education scientific research infrastructure public health environmental protection administration already willing say going increase non defense discretionary spending  7 percent chairman small influential house freedom caucus said program saying enough need give government pay raise 10 11 percent fiscal conservative see rationale  eventually run people money said among late party debt tax overhaul balloon federal budget deficit add 1 5 trillion 10 20 trillion national debt interesting hear mark talk fiscal responsibility democratic  representative said republican tax bill would require united borrow 1 5 trillion future finance tax rich one least  fiscally responsible ever seen history house think going paying many come said insist tax package biggest  tax overhaul 30 boost economy job growth house speaker also tax bill recently went making clear radio interview welfare entitlement reform party often would top republican priority 2018 republican parlance entitlement mean food housing assistance health insurance elderly poor disabled well assist needy early saying would try pay tax overhaul seeking spending social house may take back seat senate approve budget prevent government shutdown use leverage senate narrowly control defend discretionary non defense social spending tackling issue people brought illegally country trump put march 2018 expiration date deferred action childhood program young deportation work president said recent twitter border wall immigration law exchange agreeing help representative told favor linking issue policy wall need clean said trump meet congressional discuss weekend strategy sessions trump republican 6 7 white house said trump also meet republican governor rick emergency aid house 81 billion aid package far 44 billion trump administration senate yet aid'

# %%
features = df['text']
targets = df['label']

X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.20, random_state=18)

# %%
max_vocab = 10000
tokenizer = Tokenizer(num_words=max_vocab)
tokenizer.fit_on_texts(X_train)

# %%
# tokenize the text into vectors
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, padding='post', maxlen=256)
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, padding='post', maxlen=256)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(max_vocab, 128),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64,  return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1)
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 128)         1280000
#
#  bidirectional (Bidirection  (None, None, 128)         98816
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 32)                18560
#  onal)
#
#  dense (Dense)               (None, 64)                2112
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1399553 (5.34 MB)
# Trainable params: 1399553 (5.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(1e-4),
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=10,validation_split=0.1, batch_size=30, shuffle=True, callbacks=[early_stop])
# Out:
# Epoch 1/10
# 1073/1073 [==============================] - 715s 658ms/step - loss: 0.2429 - accuracy: 0.8784 - val_loss: 0.0780 - val_accuracy: 0.9785
# Epoch 2/10
# 1073/1073 [==============================] - 622s 580ms/step - loss: 0.0695 - accuracy: 0.9806 - val_loss: 0.0726 - val_accuracy: 0.9765
# Epoch 3/10
# 1073/1073 [==============================] - 621s 579ms/step - loss: 0.0421 - accuracy: 0.9901 - val_loss: 0.0575 - val_accuracy: 0.9838
# Epoch 4/10
# 1073/1073 [==============================] - 620s 577ms/step - loss: 0.0289 - accuracy: 0.9940 - val_loss: 0.0624 - val_accuracy: 0.9832
# Epoch 5/10
# 1073/1073 [==============================] - 623s 580ms/step - loss: 0.0192 - accuracy: 0.9968 - val_loss: 0.0639 - val_accuracy: 0.9843

# %%
loss,accuracy=model.evaluate(X_test, y_test)
print("Loss of the Model: ",loss)
print("Accuracy of the Model: ", accuracy)
# Out:
# 280/280 [==============================] - 40s 141ms/step - loss: 0.0654 - accuracy: 0.9808
# Loss of the Model:  0.06538015604019165
# Accuracy of the Model:  0.9807563424110413

# %%
pred = model.predict(X_test)

binary_predictions = []

for i in pred:
    if i >= 0.5:
        binary_predictions.append(1)
    else:
        binary_predictions.append(0)
# Out:
# 280/280 [==============================] - 44s 144ms/step

# %%
print('Accuracy on testing set:', accuracy_score(binary_predictions, y_test))
print('Precision on testing set:', precision_score(binary_predictions, y_test))
print('Recall on testing set:', recall_score(binary_predictions, y_test))
# Out:
# Accuracy on testing set: 0.9807563213246812
# Precision on testing set: 0.9764650506001412
# Recall on testing set: 0.9829424307036247

# %%
matrix = confusion_matrix(binary_predictions, y_test, normalize='all')
plt.figure(figsize=(16, 10))
ax = plt.subplot()
sns.heatmap(matrix, annot=True, ax=ax, cmap='Greens')

# Labels, title, and ticks
ax.set_xlabel('Predicted Labels', size=20)
ax.set_ylabel('True Labels', size=20)
ax.set_title('Confusion Matrix', size=20)
ax.xaxis.set_ticklabels([0, 1], size=15)
ax.yaxis.set_ticklabels([0, 1], size=15)

plt.show()
